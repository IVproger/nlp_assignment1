# %% [markdown]
# # Context-sensitive Spelling Correction
#
# The goal of the assignment is to implement context-sensitive spelling correction. The input of the code will be a set of text lines and the output will be the same lines with spelling mistakes fixed.
#
# Submit the solution of the assignment to Moodle as a link to your GitHub repository containing this notebook.
#
# Useful links:
# - [Norvig's solution](https://norvig.com/spell-correct.html)
# - [Norvig's dataset](https://norvig.com/big.txt)
# - [Ngrams data](https://www.ngrams.info/download_coca.asp)
#
# Grading:
# - 60 points - Implement spelling correction
# - 20 points - Justify your decisions
# - 20 points - Evaluate on a test set

# %% [markdown]
# ## Implement context-sensitive spelling correction
#
# Your task is to implement context-sensitive spelling corrector using N-gram language model. The idea is to compute conditional probabilities of possible correction options. For example, the phrase "dking sport" should be fixed as "doing sport" not "dying sport", while "dking species" -- as "dying species".
#
# The best way to start is to analyze [Norvig's solution](https://norvig.com/spell-correct.html) and [N-gram Language Models](https://web.stanford.edu/~jurafsky/slp3/3.pdf).
#
# When solving this task, we expect you'll face (and successfully deal with) some problems or make up the ideas of the model improvement. Some of them are:
#
# - solving a problem of n-grams frequencies storing for a large corpus;
# - taking into account keyboard layout and associated misspellings;
# - efficiency improvement to make the solution faster;
# - ...
#
# Please don't forget to describe such cases, and what you decided to do with them, in the Justification section.
#
# ##### IMPORTANT:
# Your project should not be a mere code copy-paste from somewhere. You must provide:
# - Your implementation
# - Analysis of why the implemented approach is suggested
# - Improvements of the original approach that you have chosen to implement

# %%
# Your code here

# %% [markdown]
# ## Justify your decisions
#
# Write down justificaitons for your implementation choices. For example, these choices could be:
# - Which ngram dataset to use
# - Which weights to assign for edit1, edit2 or absent words probabilities
# - Beam search parameters
# - etc.

# %% [markdown]
# *Your text here...*

# %% [markdown]
# ## Evaluate on a test set
#
# Your task is to generate a test set and evaluate your work. You may vary the noise probability to generate different datasets with varying compexity (or just take another dataset). Compare your solution to the Norvig's corrector, and report the accuracies.

# %%
# Your code here

# %% [markdown]
# #### Useful resources (also included in the archive in moodle):
#
# 1. [Possible dataset with N-grams](https://www.ngrams.info/download_coca.asp)
# 2. [Damerau–Levenshtein distance](https://en.wikipedia.org/wiki/Damerau–Levenshtein_distance#:~:text=Informally%2C%20the%20Damerau–Levenshtein%20distance,one%20word%20into%20the%20other.)

# %% [markdown]
# # Solution pipeline
#
# * Choose dataset for the
# * Implement the baseline model https://norvig.com/spell-correct.html and collet metrics on test dataset.
# * Test dataset: https://titan.dcs.bbk.ac.uk/~roger/holbrook-tagged.dat

# %% [markdown]
# # Norvig's solution

# %%
import re
from collections import Counter

def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open('data/train/big.txt').read()))

# %%
def P(word, N=sum(WORDS.values())): 
    "Probability of `word`."
    return WORDS[word] / N

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
# Read the text from the file
file_path = 'data/test/test.txt'
with open(file_path, 'r') as file:
    text = file.read()

# %%
text
# Out:
# '1.\nNIGEL THRUSH page 48 \n\n I have four in my Family Dad Mum and <ERR targ=sister> siter </ERR> .\nMy Dad works at Melton.\nMy <ERR targ=sister> siter </ERR> <ERR targ=goes> go </ERR> to Tonbury.\nMy Mum goes out <ERR targ=sometimes> some times </ERR> .\nI go to Bridgebrook i go out <ERR targ=sometimes> some times </ERR> on Tuesday night i go to Youth <ERR targ=club> clob </ERR> .\nOn thursday nights I go <ERR targ=bellringing> bell ringing </ERR> on Saturdays I go down to the farm.\non sundays I go to church.\nI go to bed at 10 o clock I <ERR targ=watch> wakh </ERR> TV at 5 o clock I live in a house.\nThe house is in the world.\nI live at Boar Parva it is near Melton and Bridgebrook and Smallerden.\nThe house is white it has stone up the <ERR targ=front> frount </ERR> it is the first from Bridgebrook and the <ERR targ=second> sexeon </ERR> from Smallerden.\nMy Mum is at home She goes to the shop on fridays My Dad goes to work at Smallerden .\n\n What I do when I get home from school.\nOn monday I sometimes go down the farm in the night I <ERR targ=watch> wach </ERR> TV there is BBC and I.T.V.\nI like I.T.V.\nWe call Anglia I.T.V.\nWe have got Anglia like to <ERR targ=watch> wach </ERR> <ERR targ=cowboys> cow Boys </ERR> .\nOn Tuesday I get off the bus and <ERR targ=sometimes> some times </ERR> in the night I go to the Youth <ERR targ=club> colbe </ERR> .\nI like to <ERR targ=watch> wach </ERR> T.V.\nthere is a lot of things on T.V.\nI <ERR targ=watch> wach </ERR> it each night.\n.\nI <ERR targ=think> thing </ERR> <ERR targ=TV> tv </ERR> is good but people say it gives us <ERR targ=square> squar </ERR> <ERR targ=eyes> iyes </ERR> .\n\n The Murder Car.\n1 night when it was dark about 12 <ERR targ=o\'clock> oclock </ERR> a man was <ERR targ=knocked> nock </ERR> down by a car.\nThe body was found <ERR targ=at> a </ERR> 7 <ERR targ=o\'clock> oclock </ERR> in the morning.\nThe name of the man who was <ERR targ=killed> kild </ERR> was Jack Robbinson he has black hair brown eyes blue Jacket and blue Jeans.\nNo one <ERR targ=saw> see </ERR> the car.\nthere had <ERR targ=been> bean </ERR> a lot of people <ERR targ=knocked> nock </ERR> down by a car so they <ERR targ=called> cald </ERR> it the murder car.\nThe Police <ERR targ=came> cam </ERR> out to look for the car.\nThe other cars were black so one of the other people said.\nThe murder man has a black beard The next day one of the policemen were <ERR targ=killed> killd </ERR> the next day they found the car over the Hill <ERR targ=there> the </ERR> was the man near it he was dead.\n\n I kissed a girl one night <ERR targ=Her> Here </ERR> <ERR targ=eyes> iyes </ERR> were burning blue She said o do you love me Of course of course I do.\n\n Bell Ringing.\nWhen you start Bell Ringing you <ERR targ=have to> haveto </ERR> ring a bell <ERR targ=before> be for </ERR> you can do <ERR targ=anything> any thing </ERR> <ERR targ=else> als </ERR> .\nIt takes a lot to ring a bell on the rope there is a sally.\nON the bell there is a <ERR targ=wheel> weel </ERR> .\nthe <ERR targ=wheel> weel </ERR> has the rope on it some <ERR targ=sallies> sally </ERR> are green and the <ERR targ=others> other </ERR> are red white and blue.\nWhen you can ring.\nYou have to ring <ERR targ=rounds> rouns </ERR> that is when you go 123456 when you can <ERR targ=do> don </ERR> that.\nYou <ERR targ=ring> rings </ERR> like this.\nThese are the names of them Plain Hunt, plain Bob, Grandsire Doubles.\nGrandsire Triples it takes a long time to ring them.\nI have been ringing a long time we go to Smallerden and Oakwell and Guildwell we will <ERR targ=be> we </ERR> going to Smallerden this Thursday I ring 1 2 and 3 but not 4 5 and 6 I like going bell ringing, some time the bell <ERR targ=breaks> brakes </ERR> And the rope goes up and if you are not <ERR targ=careful> carfull </ERR> you will go up with it, we start at 7.30 and end at 9.oclock.\nMe and my dad bike to Melton.\n\n THE SICK SOW OF THE ARMY COURT\nOne day Sergent S ...

# %%
def extract_errors(text):
    # Regular expression to find error cases
    error_pattern = re.compile(r'<ERR targ=(.*?)> (.*?) </ERR>')
    errors = error_pattern.findall(text)
    return errors


def extract_context(text, n):
    # Split the text into words, excluding error tags and erroneous words
    words = re.split(r'\s+', re.sub(r'<ERR targ=.*?>.*?</ERR>', '', text))
    # Regular expression to find error cases
    error_pattern = re.compile(r'<ERR targ=(.*?)> (.*?) </ERR>')
    contexts = []

    for match in error_pattern.finditer(text):
        start, end = match.span()
        # Find the position of the error in the word list
        error_position = len(re.split(r'\s+', text[:start])) - 1
        # Extract the context before the error
        context_start = max(0, error_position - n)
        context = words[context_start:error_position]
        contexts.append((match.group(1), match.group(2), context))

    return contexts

# %%
# Extract errors
errors = extract_errors(text)
print("Extracted Errors:")
for error in errors:
    print(error)
# Out:
# Extracted Errors:
# ('sister', 'siter')
# ('sister', 'siter')
# ('goes', 'go')
# ('sometimes', 'some times')
# ('sometimes', 'some times')
# ('club', 'clob')
# ('bellringing', 'bell ringing')
# ('watch', 'wakh')
# ('front', 'frount')
# ('second', 'sexeon')
# ('watch', 'wach')
# ('watch', 'wach')
# ('cowboys', 'cow Boys')
# ('sometimes', 'some times')
# ('club', 'colbe')
# ('watch', 'wach')
# ('watch', 'wach')
# ('think', 'thing')
# ('TV', 'tv')
# ('square', 'squar')
# ('eyes', 'iyes')
# ("o'clock", 'oclock')
# ('knocked', 'nock')
# ('at', 'a')
# ("o'clock", 'oclock')
# ('killed', 'kild')
# ('saw', 'see')
# ('been', 'bean')
# ('knocked', 'nock')
# ('called', 'cald')
# ('came', 'cam')
# ('killed', 'killd')
# ('there', 'the')
# ('Her', 'Here')
# ('eyes', 'iyes')
# ('have to', 'haveto')
# ('before', 'be for')
# ('anything', 'any thing')
# ('else', 'als')
# ('wheel', 'weel')
# ('wheel', 'weel')
# ('sallies', 'sally')
# ('others', 'other')
# ('rounds', 'rouns')
# ('do', 'don')
# ('ring', 'rings')
# ('be', 'we')
# ('breaks', 'brakes')
# ('careful', 'carfull')
# ("Cynthia's", 'Cynthia')
# ('gas', 'gass')
# ('masks', 'marsks')
# ('floor', 'foor')
# ('what', 'wat')
# ('gas', 'gass')
# ('masks', 'marsks')
# ('too', 'to')
# ('what', 'wat')
# ('wash', 'wosh')
# ('perhaps', 'prasp')
# ('ate', 'et')
# ('before', 'be for')
# ('his', 'is')
# ('pony', 'poney')
# ('whiskey', 'wiskey')
# ('soap', 'soape')
# ('whiskey', 'wiskey')
# ('gave', 'cave')
# ('gave', 'cave')
# ('got', 'go')
# ('her', 'here')
# ('her', 'here')
# ('soap', 'sope')
# ('what', 'wat')
# ('her', 'here')
# ('gave', 'cave')
# ('whiskey', 'wiskey')
# ('soap', 'sope')
# ('gave', 'cave')
# ('never', 'knver')
# ("that's", 'thats')
# ('killed', 'kild')
# ('wait', 'wate')
# ('inject', 'injeck')
# ('make', 'mack')
# ('sure', 'shore')
# ('dry', 'drye')
# ('fork', 'falk')
# ('knock', 'nock')
# ('themselves', 'them souve')
# ('them', 'the')
# ('worm', 'worme')
# ('powder', 'pouder')
# ('worm', 'worme')
# ('get', 'ge')
# ('their', 'there')
# ('them', 'theme')
# ('keep', 'geep')
# ('sure', 'shore')
# ('has', 'as')
# ('enough', 'a nougth')
# ('can', 'came')
# ('for', 'of')
# ('fattening', 'fating')
# ('eat', 'eate')
# ('bigger', 'biger')
# ('fattening', 'fating')
# ('when', 'whe')
# ('ones', 'wones')
# ('are', 'and')
# ('big', 'bing')
# ('weighing', 'waying')
# ('weighed', 'waid')
# ('ready', 'reddy')
# ('killed', 'kild')
# ('too', 'to')
# ('Him', 'Im')
# ('Him', 'Im')
# ('too', 'to')
# ('for', 'fro')
# ('they', 'the')
# ('too', 'to')
# ('Troy', 'Toy')
# ('thought', 'though')
# ('Royal', 'Royl')
# ('fast', 'farst')
# ('Royal', 'Royl')
# ('?', 'Consulatoin')
# ('Royal', 'Royl')
# ('Royal', 'Royl')
# ('Japanese', 'Japannese')
# ('Honda', 'Hondor')
# ('fast', 'farst')
# ('getting', 'geting')
# ('his', 'is')
# ('leg', 'lege')
# ('another', 'a nouther')
# ('hurt', 'hearte')
# ('his', 'is')
# ("don't", 'dont')
# ('think', 'thing')
# ('saw', 'sow')
# ('sidecar', 'side car')
# ('turn', 'turne')
# ('sidecar', 'side care')
# ('motorbike', 'motor bike')
# ("don't", 'dont')
# ('know', 'no')
# ('happened', 'hapend')
# ('hurt', 'heart')
# ('motorbike', 'moter bike')
# ('spun', 'spund')
# ('motorbike', 'moter bike')
# ('caught', 'caugh')
# ('blew', 'blow')
# ('petrol', 'petal')
# ('soon', 'sone')
# ('There', 'They')
# ('final', 'fianl')
# ('Royal', 'Royl')
# ('Honda', 'Hondor')
# ('Triumph', 'Triumh')
# ("they're", 'there')
# ('Triumph', 'trumh')
# ('Honda', 'Hondor')
# ('going', 'go')
# ("he's", 'his')
# ('won', 'one')
# ('Royal', 'Royl')
# ('Honda', 'Hondor')
# ('shone', 'shon')
# ('ploughed', 'ploud')
# ('done', 'don')
# ('a', 'an')
# ('had', 'hade')
# ('cleaned', 'cleand')
# ('for', 'fore')
# ('potatoes', 'potato')
# ('pathway', 'parth way')
# ('ploughed', 'ploud')
# ('heavy', 'hevey')
# ('like', 'look')
# ('pearls', 'pirls')
# ('nearly', 'nealy')
# ('touched', 'toch')
# ('piece', 'pice')
# ('cleaned', 'cleand')
# ('break', 'brack')
# ('hopped', 'hop')
# ('popped', 'poped')
# ('whistled', 'wisheld')
# ('chirped', 'cherped')
# ('tried', 'trid')
# ('catch', 'chach')
# ('bird', 'brid')
# ('bird', 'brid')
# ('know', 'no')
# ("can't", "carn't")
# ('know', 'no')
# ("we're", 'were')
# ('wanted', 'whanted')
# ("you're", 'your')
# ('wanted', 'whated')
# ('Goodbye', 'Good by')
# ('leaves', 'leavs')
# ('apples', 'apple')
# ('autumn', 'Aount')
# ('you', 'yow')
# ('cores', 'corres')
# ('cores', 'corres')
# ('you', 'yow')
# ('throw', 'thorght')
# ('cores', 'corres')
# ('burn', 'brun')
# ('orchard', 'orcher')
# ('climb', 'clim')
# ('them', 'then')
# ('them', 'then')
# ('earwigs', 'eyewigs')
# ('their', 'there')
# ('pockets', 'pocket')
# ('apples', 'apple')
# ('full', 'fall')
# ('apples', 'apple')
# ('them', 'then')
# ('hanging', 'haing')
# ('them', 'then')
# ('them', 'then')
# ('want', 'whant')
# ('hairdresser', 'hair dreser')
# ('want', 'whant')
# ('want', 'whont')
# ('married', 'marryid')
# ('twenty one', 'twentone')
# ('husband', 'husbon')
# ('take', 'tack')
# ('want', 'whant')
# ('want', 'whant')
# ('want', 'whont')
# ('Butlins', 'butlins')
# ('honeymoon', 'hunemoon')
# ('sculpture', 'sculptor')
# ('model', 'modal')
# ('thing', 'think')
# ('model', 'modal')
# ('standing', 'staning')
# ('modelled', 'malod')
# ('model', 'molad')
# ('thing', 'think')
# ('calmer', 'comer')
# ('carefully', 'caresll')
# ('people', 'peolpe')
# ('cruel', 'corller')
# ('catch', 'cash')
# ('their', 'there')
# ('carrying', 'carring')
# ('one', 'on')
# ('Wings', 'Wing')
# ('break', 'brick')
# ("man's", 'mans')
# ('swans', 'swan')
# ('delicate', 'dellitent')
# ('things', 'think')
# ('Poem', 'Pome')
# ("daren't", 'darnt')
# ("didn't", 'dident')
# ('quietly', 'quitely')
# ('Their', 'There')
# ('beating', 'beting')
# ('rapidly', 'raperly')
# ("I'm", 'I')
# ('MARY', 'MARRY')
# ('here', 'hear')
# ('make', 'mack')
# ("What's", 'What')
# ('wrong', 'wong')
# ('MARY', 'MARRY')
# ('taking', 'thaing')
# ('out', 'owt')
# ('tonight', 'to night')
# ('MARY', 'MARRY')
# ("it's", 'it')
# ('fault', 'falt')
# ("it's", 'its')
# ('fault', 'falt')
# ('trying', 'traing')
# ('MARY', 'MARRY')
# ("you've", 'you')
# ('choosing', 'ching')
# ('better', 'bet')
# ("there's", 'theres')
# ("What's", 'What')
# ('slammed', 'slander')
# ("can't", 'carnt')
# ('talk', 'tallk')
# ('decision', 'disson')
# ('instance', 'instead')
# ("there's", 'theres')
# ("There's", 'There')
# ('no', 'on')
# ('else', 'eles')
# ('is', 'us')
# ("it's", 'its')
# ('trying', 'trining')
# ('then', 'them')
# ('rough', 'rought')
# ('scream', 'scem')
# ('scares', 'scards')
# ('warned', 'wornd')
# ('you', 'yew')
# ('you', 'yow')
# ('you', 'yow')
# ('want', 'whant')
# ('hurt', 'hert')
# ('hurt', 'hert')
# ("you're", 'yow')
# ('wrong', 'rong')
# ('you', 'yow')
# ('any', 'eney')
# ('you', 'yow')
# ('tonight', 'to night')
# ('know', 'no')
# ('you', 'yow')
# ("o'clock", 'o, clock')
# ("You're", 'Your')
# ("don't", 'dont')
# ('know', 'no')
# ('goodbye', 'goodby')
# ('tonight', 'to night')
# ('character', 'charickter')
# ('Their', 'There')
# ('their', 'there')
# ('you', 'yow')
# ('who', 'how')
# ('asking', 'arsking')
# ('you', 'yow')
# ('else', 'els')
# ("you'll", 'your')
# ('yourself', 'your self')
# ('enough', 'engouh')
# ("you'll", 'your')
# ("that's", 'thats')
# ('enough', 'engouh')
# ("I'll", 'I')
# ("that's", 'thats')
# ('upstairs', 'up stairs')
# ("She's", 'She')
# ('whatever', 'what ever')
# ('happens', 'happends')
# ("boyfriend's", 'boyfrends')
# ('opened', 'opend')
# ('here', 'hear')
# ('So', 'Show')
# ('have', 'has')
# ("Let's", 'Lets')
# ("that's", 'thats')
# ('want', 'whont')
# ("let's", 'lets')
# ('something', 'somethink')
# ('happily', 'happly')
# ('you', 'yow')
# ('story', 'stors')
# ('works', 'work')
# ('factory', 'factoy')
# ('works', 'wors')
# ('?', 'nsor')
# ('Watson', 'watston')
# ('works', 'wonrs')
# ('greenhouse', 'gnenhouen')
# ('excited', 'exited')
# ('went', 'wetn')
# ('to', 'two')
# ('His', 'He')
# ('mother', 'mouthr')
# ('said', 'sald')
# ('?', 'nis')
# ('sneaking', 'sneking')
# ('teddy boy', 'tedeboy')
# ('sneaking', 'sneking')
# ('to', 'two')
# ('waited', 'wated')
# ('teddy boy', 'tedeboy')
# ('teddy boy', 'tedeboy')
# ('came', 'kom')
# ('outside', 'out sild')
# ('sneaking', 'sneking')
# ('Teddy boy', 'Tedeboy')
# ('teddy boy', 'tedeboy')
# ('One', 'Won')
# ('farmer', 'frm')
# ('for', 'four')
# ('vet', 'vethn')
# ("wasn't", "whdn't")
# ('healthy', 'hethy')
# ('and', 'an')
# ('fit', 'fanit')
# ('farmer', 'frm')
# ('said', 'sidn')
# ('vet', 'vethn')
# ('unhealthy', 'on hethy')
# ('vet', 'vethu')
# ('said', 'sidn')
# ('farmer', 'frmh')
# ('come', 'kumh')
# ('old', 'lod')
# ('said', 'sidn')
# ('vet', 'vethn')
# ('farmer', 'frmh')
# ('to', 'two')
# ('old', 'lod')
# ('vet', 'vethn')
# ('farmer', 'frmh')
# ('old', 'lod')
# ('said', 'sidn')
# ('farmer', 'frmh')
# ('farm', 'frm')
# ('farmer', 'frmh')
# ('out', 'ouht')
# ('laid', 'ladh')
# ('farmer', 'frmh')
# ('too', 'two')
# ('behind', 'behism')
# ('farmer', 'frmh')
# ('his', 'he')
# ('?', 'bav')
# ('two', 'to')
# ('lay', 'ladh')
# ('vet', 'vetin')
# ('vet', 'vent')
# ('what', 'wat')
# ('wrong', 'ron')
# ('with', 'wis')
# ('sleep', 'seph')
# ('vet', 'vethn')
# ('to', 'two')
# ("farmer's", 'frmh')
# ('vet', 'vethn')
# ('farmer', 'framh')
# ('vet', 'vethn')
# ('said', 'sidn')
# ('to', 'two')
# ('asleep', 'a seph')
# ('vet', 'vethn')
# ('farmer', 'frmh')
# ('?', 'sechrus')
# ("pigs'", 'pigs')
# ('laid', 'ladh')
# ('sleep', 'seph')
# ('farmer', 'frmh')
# ('vet', 'vethn')
# ('back', 'bakh')
# ('farmer', 'frmh')
# ('went', 'weth')
# ('?', 'ruth')
# ('?', 'humit')
# ('woke', 'wok')
# ('better', 'beththe')
# ('End', 'And')
# ('you', 'your')
# ('hands', 'hand')
# ('sing', 'sings')
# ('done', 'don')
# ('our', 'ous')
# ('the', 'ge')
# ('sun', 'son')
# ('And', 'Ane')
# ('Teddy boy', 'Teddoy')
# ('start', 'starte')
# ('trouble', 'troefle')
# ('teddy boy', 'teddoy')
# ('Teddy boy', 'Teddoy')
# ('round', 'rownd')
# ('Teddy boy', 'Teddoy')
# ('to', 'two')
# ('pictures', 'pictyres')
# ('manager', 'maneger')
# ('stairs', 'stars')
# ('woman', 'women')
# ('she', 'he')
# ('?', 'Hurbured')
# ('landed', 'laded')
# ('kitchen', 'kitching')
# ('meadow', 'meadoy')
# ('confide', 'cornfield')
# ('daffodils', 'daffodill')
# ('?', 'crowsed')
# ('head', 'hed')
# ('was', 'wos')
# ('teddy boys', 'teddyboys')
# ('big-headed', 'Big  haded')
# ('want', 'wat')
# ('Teddy boys', 'Taddyboys')
# ('about', 'a Bat')
# ('knife', 'kniffe')
# ('shop', 'shap')
# ('cafe', 'kiffe')
# ('to', 'two')
# ('to', 'two')
# ('teddy boys', 'teddyboys')
# ('knife', 'kiffe')
# ('too', 'two')
# ('dangerous', 'dangers')
# ('they', 'the')
# ('trying', 'try')
# ('car', 'Star')
# ('questioned', 'question')
# ('End', 'ANd')
# ('died', 'ded')
# ('him', 'hm')
# ('himself', 'his self')
# ('End', 'ANd')
# ('story', 'hio')
# ('steal', 'still')
# ('cops', 'caps')
# ('and', 'an')
# ('cops', 'caps')
# ('came', 'kum')
# ('End', 'And')
# ('story', 'shio')
# ('sweets', 'swet')
# ('was', 'wos')
# ('waiting', 'waten')
# ('guilty', 'guilt')
# ('End', 'ANd')
# ('police', 'polic')
# ('police', 'polic')
# ('came', 'cam')
# ('police', 'polic')
# ('went', 'wen')
# ('see', 'se')
# ('her', 'She')
# ('went', 'wen')
# ('it', 'she')
# ('time', 'tim')
# ('come', 'coum')
# ('End', 'And')
# ('to', 'two')
# ('man', 'mae')
# ('to', 'two')
# ('Police', 'Pollce')
# ('did', 'ded')
# ('old', 'lod')
# ('for', 'four')
# ('murdered', 'murbur')
# ('murder', 'murber')
# ('End', 'And')
# ('story', 'shio')
# ('tramps', 'trmp')
# ('tramp', 'trmp')
# ('road', 'rod')
# ('tramp', 'trmp')
# ('tramp', 'trmp')
# ('what', 'wat')
# ('want', 'woth')
# ('said', 'sald')
# ('tramp', 'trmp')
# ('eyes', 'eyey')
# ('he', 'the')
# ('followed', 'fellowed')
# ('said', 'sid')
# ('home', 'hom')
# ('said', 'sid')
# ('said', 'sid')
# ('End', 'And')
# ('locked', 'lockEd')
# ('road', 'rad')
# ('man', 'manh')
# ('man', 'manh')
# ('man', 'mand')
# ('his', 'he')
# ('standard', 'stardnd')
# ('ten', 'tan')
# ('Yard', 'Ysid')
# ('End', 'And')
# ("Tom's", 'Toms')
# ('stinks', 'sticks')
# ('mother', 'morther')
# ('trashy', 'tashie')
# ('field', 'fed')
# ('fish', 'fsh')
# ('air', 'hare')
# ('water-rat', 'waterrat')
# ('field', 'fed')
# ('to', 'two')
# ('school', 'shool')
# ('come', 'com')
# ('sea', 'see')
# ('sea', 'see')
# ('sea', 'see')
# ('sea', 'see')
# ('feet', 'fet')
# ('to', 'two')
# ('Porky', 'Paulkey')
# ('to', 'two')
# ('he', 'the')
# ('ambulance', 'amblance')
# ('to', 'tow')
# ('to', 'two')
# ('dying', 'dieing')
# ('home', 'homse')
# ('to', 'two')
# ('door', 'boor')
# ('to', 'qu')
# ('wall', 'molh')
# ('roof', 'rhfn')
# ('chimney', 'cimbenr')
# ('fire', 'fiar')
# ('jumped', 'jumth')
# ('his', 'he')
# ('seat', 'sat')
# ('over', 'ove')
# ('out', 'ou')
# ('to', 'two')
# ('wall', 'wah')
# ('to', 'two')
# ('the', 'he')
# ('went', 'wens')
# ('army', 'hrmehr')
# ("didn't", 'denat')
# ('like', 'lichr')
# ('army', 'hrmehn')
# ('leave', 'lefnr')
# ("didn't", 'dednt')
# ('come', 'comr')
# ('douche', 'back')
# ('by', 'bihr')
# ('captain', 'cpn')
# ('said', 'sedn')
# ('back', 'doc')
# ('yet', 'yeth')
# ('down', 'dus')
# ('?', 'unz')
# ('road', 'rod')
# ('London', 'Londod')
# ('think', 'thank')
# ('think', 'tink')
# ('idea', 'ida')
# ('yours', 'yourns')
# ('circus', 'sercus')
# ('around', 'a round')
# ('pointing', 'pooting')
# ('meadow', 'medow')
# ('road', 'raod')
# ('siren', 'satren')
# ('hammering', 'hemmsering')
# ('many', 'meny')
# ('metals', 'metet')
# ('or', 'ot')
# ('dance', 'dane')
# ('young', 'yung')
# ('peep', 'peope')
# ('dancing', 'pncing')
# ('?', 'anetes')
# ('got', 'gnt')
# ('There', 'They')
# ("dad's", 'dads')
# ("mum's", 'mums')
# ('married', 'marrede')
# ('months', 'month')
# ('company', 'coperney')
# ('person', 'peason')
# ('picked', 'picted')
# ('says', 'sais')
# ('says', 'seis')
# ('says', 'sais')
# ('says', 'sais')
# ('Sylvia', 'sylver')
# ('Sylvia', 'Sylver')
# ('says', 'sais')
# ('no one', 'now one')
# ("that's", 'thats')
# ('Macwilliams', 'macwillaims')
# ('pulled', 'pull')
# ('which', 'witch')
# ('kitchen', 'kichen')
# ('threw', 'frow')
# ('Macwilliams', 'macwillaims')
# ('forward', 'forword')
# ('almighty', 'almity')
# ('died', 'diad')
# ('lived', 'lifd')
# ('council', 'counsel')
# ('outside', 'out side')
# ('London', 'Londen')
# ('went', 'whenet')
# ('fighting', 'figthing')
# ('grown', 'groon')
# ('Joan', 'Jone')
# ('too', 'to')
# ('nevertheless', 'never the less')
# ('died', 'diad')
# ('there', 'they')
# ('of', 'off')
# ('slowly', 'slolly')
# ('stopped', 'stoped')
# ('until', 'untill')
# ('had', 'have')
# ('he', 'his')
# ('carried', 'carred')
# ('be', 'me')
# ('destroyed', 'distrod')
# ('baths', 'bath')
# ('clean', 'clearn')
# ("I'm", 'Im')
# ('allowed', 'alloud')
# ('programmes', 'programes')
# ('suitable', 'surtebull')
# ('there', 'they')
# ('unfit', 'unfitt')
# ('others', 'other')
# ('stabbed', 'stabed')
# ('of', 'off')
# ('boasting', 'bosting')
# ('paid', 'payed')
# ('employment', 'imployment')
# ('sitting', 'siting')
# ('stuffy', 'stufy')
# ('apprenticeship', 'apprentiship')
# ('classes', 'classis')
# ('once', 'ones')
# ('useful', 'usfull')
# ('While', 'Will')
# ('getting', 'get')
# ('shillings', 'shilling')
# ('Apprenticeship', 'Apprentiship')
# ('of', 'off')
# ('chosen', 'choosen')
# ('career', 'carrer')
# ('different', 'diffrent')
# ('anything', 'enthing')
# ('working', 'work')
# ('given', 'give')
# ('leave', 'life')
# ('wants', 'want')
# ('always', 'all ways')
# ('do', 'done')
# ('sometimes', 'some thime')
# ('yours', 'you')
# ('There', 'They')
# ('and', 'a')
# ('brothers', 'brother')
# ('sisters', 'sister')
# ('comes', 'come')
# ('?', 'Half-hose')
# ('likes', 'like')
# ('wavy', 'wavey')
# ('boyfriend', 'boyfrend')
# ('hates', 'hate')
# ('prayer-book', 'prayerbook')
# ('colour', 'colur')
# ('clothes', 'colhes')
# ('dense', 'dence')
# ('CHARACTERS', 'CHARTORS')
# ('asks', 'ask')
# ("boy's", 'boys')
# ("haven't", "haven's")
# ('prettiest', 'prettest')
# ('answered', 'anwerd')
# ('asked', 'ask')
# ('her', 'he')
# ('here', 'hear')
# ('comes', 'come')
# ("Whoever's", 'Whos evers')
# ("Jean's", 'jeans')
# ('Cheerio', 'Cheere ho')
# ("Joyce's", 'Joyce')
# ('parents', 'prarents')
# ("whoever's", 'who evers')
# ('parents', 'prerents')
# ('go', 'do')
# ('pictures', 'picture')
# ('walked', 'walk')
# ("Jean's", 'Jeans')
# ('he', 'the')
# ('Roy', 'Roys')
# ("o'clock", 'O clock')
# ('their', 'they')
# ('cheerio', 'cheeroh')
# ("don't", 'want')
# ('the', 'they')
# ('their', 'there')
# ('got', 'go')
# ("wasn't", 'wasnt')
# ('myself', 'my shelf')
# ('stopped', 'stop')
# ("Joyce's", 'Joyce')
# ('Motorbike', 'Motor-bikes')
# ('they', 'there')
# ('night', 'tonight')
# ('went', 'sent')
# ('over', 'ove')
# ("John's", 'John')
# ('introduced', 'introducted')
# ('decided', 'dicide')
# ('Married', 'Marrid')
# ('special', 'spicil')
# ('the', 'they')
# ('Their', 'There')
# ('engagement', 'enagement')
# ('engaged', 'enaged')
# ('presents', 'present')
# ('too', 'two')
# ('the', 'they')
# ('walked', 'walk')
# ('their', 'they')
# ('their', 'they')
# ('decided', 'decider')
# ('children', 'chidren')
# ("Adam's", 'Adam')
# ('what', 'want')
# ("don't", 'don')
# ('beverley', 'beverly')
# ('sisters', 'sister')
# ('know', 'no')
# ('beverley', 'beverly')
# ('beverley', 'beverly')
# ('drunk', 'druck')
# ('things', 'thinks')
# ('was', 'we')
# ('painted', 'panted')
# ('outside', 'out side')
# ('happening', 'happing')
# ('fashioned', 'fashion')
# ('Their', 'They')
# ('their', 'they')
# ("grandpa's", 'grandpas')
# ('outside', 'out side')
# ('His', "He's")
# ('meant', "mean't")
# ('and', 'a')
# ('where', 'were')
# ('your', 'you')
# ('mother', 'mothers')
# ('has', 'as')
# ('its', "it's")
# ('walked', 'walk')
# ('babies', 'babys')
# ('and', 'a')
# ('asleep', 'a sleep')
# ('baby', 'babys')
# ('door', 'down')
# ('saw', 'sow')
# ('phoned', 'phone')
# ('minutes', 'minetes')
# ('outside', 'out side')
# ('and', 'aud')
# ('them', 'then')
# ('after a while', 'afterawhile')
# ('woman', 'women')
# ('policemen', 'polce men')
# ('woman', 'women')
# ('grabbed', 'grab')
# ('pounds', 'ponds')
# ('pounds', 'ponud')
# ('always', 'all ways')
# ('wherever', 'were ever')
# ('there', 'the')
# ('until', 'untill')
# ('his', "he's")
# ("girl's", 'girls')
# ('altar', 'alter')
# ('boyfriend', 'boy friend')
# ('tied', 'tired')
# ('themselves', 'they self')
# ('their', 'they')
# ('happened', 'happen')
# ('pregnant', 'pregant')
# ('their', 'they')
# ('families', 'familys')
# ('careful', 'carefull')
# ('apples', 'apple')
# ('too', 'to')
# ('especially', 'a specally')
# ('careful', 'carful')
# ('wherever', 'where ever')
# ('someone', 'some one')
# ('barbed', 'barb')
# ('probably', 'probally')
# ('they', 'the')
# ('say', 'said')
# ('recognized', 'reconnised')
# ('another', 'a nother')
# ('Stranded', 'Stranden')
# ('midsummer', "midsummer's")
# ('coral', 'corral')
# ('outfits', 'out fits')
# ('volunteered', 'volonteered')
# ('There', 'Their')
# ('bodies', 'bodys')
# ('shipwreck', 'ship wreck')
# ('There', 'Their')
# ('opened', 'open')
# ('two', 'to')
# ('then', 'the')
# ('Lucky', 'Luckily')
# ('tinned', 'tin')
# ('lifeboat', 'life boat')
# ('used', "use't")
# ('usually', 'usally')
# ('shortened', 'shortend')
# ('down', 'done')
# ('killed', 'kill')
# ('ground', 'gound')
# ('laid', 'laide')
# ('as', 'ass')
# ('evening', 'evining')
# ("father's", "farther's")
# ('reading', 'reding')
# ('coat', 'cote')
# ('hook', 'hock')
# ('dark', 'dork')
# ('GARDEN', 'GARDON')
# ('Cheetah', 'Cheter')
# ('cheetah', 'cheter')
# ('prowls', 'prouls')
# ('undergrowth', 'undergroth')
# ('jungle', 'jungel')
# ('clatter', 'clater')
# ('their', 'there')
# ('jungle', 'jungel')
# ('Monkeys', 'Munces')
# ('little', 'litel')
# ('cheetah', 'cheter')
# ('roars', 'rorse')
# ('falls', 'forls')
# ('cheetah', 'cheter')
# ('caught', 'cort')
# ('prey', 'pray')
# ('Death', 'Dearth')
# ('when', 'wen')
# ('having', 'haveing')
# ('breakfast', 'brecfast')
# ('came', 'come')
# ('bitten', 'biten')
# ("boy's", 'boys')
# ('Hong Kong', 'Honk Kong')
# ('took', 'tuck')
# ('houseboat', 'house boat')
# ('thought', 'thort')
# ('queer', 'quere')
# ('houseboat', 'house boat')
# ('were', 'where')
# ('four', 'fore')
# ('sitting', 'siting')
# ('chair', 'chere')
# ('where', 'were')
# ('entered', 'enterd')
# ("that's", 'thats')
# ('what', 'wat')
# ('bullet', 'bolot')
# ('equipment', 'aquitment')
# ('write', 'rite')
# ('piece', 'pese')
# ('what', 'wot')
# ('need', 'nede')
# ('of', 'on')
# ('once', 'wons')
# ('when', 'wen')
# ('bullet', 'bulete')
# ('wait', 'wat')
# ('what', 'wot')
# ('happened', 'hapends')
# ('Outside', 'Out side')
# ('missed', 'mist')
# ('missed', 'mist')
# ('too', 'to')
# ('man', 'may')
# ('stopped', 'stoped')
# ('bullet', 'bulet')
# ('took', 'tuck')
# ('prison', 'prisin')
# ('bullet', 'bulet')
# ('suddenly', 'suddenel')
# ('It', 'I')
# ('had', 'has')
# ('cane', 'cain')
# ('teachers', 'teacher')
# ('cane', 'cain')
# ('Bicycle', 'Bicyle')
# ('do not', 'donot')
# ('wrong', 'rong')
# ('father', 'farther')
# ('Father', 'Farther')
# ('sometimes', 'some time')
# ('pair', 'per')
# ('fly', 'fie')
# ('and', 'a')
# ('feet', 'fee')
# ('cannot', 'can not')
# ('flies', 'fies')
# ('sexton', 'sixty one')
# ('sows', 'sow')
# ('know', 'no')
# ('what', 'wot')
# ('?', 'solued')
# ('sore', 'saw')
# ('foot-and-mouth', 'footandmouth')
# ('killed', 'kid')
# ('area', 'airaear')
# ('stopped', 'stoped')
# ('After', 'Artair')
# ('there', 'their')
# ('been', 'bine')
# ('another', 'aner')
# ('outbreak', 'outdrak')
# ('foot-and-mouth', 'footanmouth')
# ('were', 'wher')
# ('killed', 'kid')
# ('selling', 'seling')
# ('sold', 'soled')
# ('them', 'the')
# ('for the', 'fort')
# ("Castle's", 'castels')
# ('me', 'we')
# ('enough', 'a nuff')
# ('build', 'buld')
# ('slaughterhouse', 'slaughthouse')
# ('asked', 'arsed')
# ('council', 'cousall')
# ('could', 'cod')
# ('build', 'billed')
# ('slaughterhouse', 'slaughthouse')
# ('council', 'counsall')
# ('replied', 'replid')
# ('could', 'cod')
# ('wrote', 'roat')
# ('biggest', 'bigest')
# ('building', 'billding')
# ('firms', 'ferman')
# ('asked', 'arsed')
# ('billed', 'build')
# ('slaughterhouse', 'slaughthouse')
# ('replied', 'replid')
# ('build', 'billd')
# ('Slaughterhouse', 'Slaughthouse')
# ('enough', 'nuff')
# ('retire', 'retier')
# ('slaughterhouse', 'slaughthouse')
# ('animals', 'animl')
# ('left', 'lift')
# ('France', 'Fance')
# ('main', 'mane')
# ('parts', 'pars')
# ('there', 'their')
# ('be', 'by')
# ('inside', 'in side')
# ('hang', 'hung')
# ('cleaned', 'clean')
# ('do', 'go')
# ("boy's", 'boy')
# ('James', 'Jame')
# ('James', 'Jame')
# ('friends', 'frens')
# ('prostitute', 'prostut')
# ('next', 'nest')
# ('James', 'Jame')
# ('telephoned', 'telphoned')
# ('seeing', 'see')
# ('again', 'agan')
# ('said', 'sed')
# ('tonight', 'to night')
# ('James', 'Jame')
# ('common', 'comon')
# ('James', 'Jame')
# ('Durex', 'Durxer')
# ('sexual', 'sexul')
# ('intercourse', 'intercors')
# ('said', 'sed')
# ('goodbye', 'good-by')
# ('later', 'lated')
# ('discovered', 'dicuverd')
# ('she', 'the')
# ('pregnant', 'pregnet')
# ('later', 'latter')
# ('Smoking', 'Smocking')
# ('house', 'houes')
# ('while', 'wil')
# ('listening', 'lsning')
# ('stairs', 'sairs')
# ('creak', 'creek')
# ('caught', 'cort')
# ('indiscreet', 'indiscrest')
# ('till', 'utill')
# ('opened', 'open')
# ('flash', 'flass')
# ("mum's", 'mums')
# ('bloody', 'bludy')
# ('Nose', 'Nos')
# ('simple', 'simpl')
# ("author's", 'others')
# ('tongue', 'tung')
# ('spies', 'spys')
# ('mouse', 'moues')
# ('skilfully', 'scill filly')
# ('creeps', 'creps')
# ('sudden', 'suden')
# ('muscles', 'musirls')
# ('tense', 'tens')
# ('springs', 'spring')
# ('squeak', 'squick')
# ('heard', 'herd')
# ("cat's", 'cats')
# ('claws', 'clors')
# ('sunk', 'sunck')
# ('quietly', 'quily')
# ('ate', 'ete')
# ('curled', 'cerled')
# ('sleep', 'slip')
# ('done', 'dun')
# ('started', 'straghted')
# ('friendly', 'frendly')
# ('James', 'Jame')
# ('James', 'Jame')
# ('Prison', 'Prisern')
# ('housebreaking', 'house braking')
# ('pickpocketing', 'pick poketin')
# ('James', 'Jame')
# ('from', 'for')
# ('tonner', 'toner')
# ('keys', 'kees')
# ('waiting', 'whating')
# ('decided', 'dicided')
# ('do', 'to')
# ('picked', 'pick')
# ('lorry', 'lory')
# ('knew', 'new')
# ('because', 'becaues')
# ('driven', 'drivern')
# ('before', 'befor')
# ('wonder', 'wund')
# ('what', 'whate')
# ('lorry', 'lory')
# ('seemed', 'semed')
# ('very', 'every')
# ('thought', 'thort')
# ('wonder', 'wund')
# ('what', 'whate')
# ('layby', 'la-by')
# ('layby', 'la-by')
# ('load', 'lod')
# ('stolen', 'stolon')
# ('climbed', 'climb')
# ('wonder', 'wunder')
# ('should', 'shod')
# ('should', 'shod')
# ('quiet', 'quiert')
# ('decided', 'dicider')
# ('carried', 'cared')
# ('down', 'donw')
# ('stopped', 'stop')
# ('load', 'lod')
# ('Austin', 'Autin')
# ('Tonner', 'Toner')
# ('have', 'hav')
# ('stopped', 'stop')
# ('because', 'becaues')
# ('lorry', 'lory')
# ('lorry', 'lory')
# ('corner', 'corer')
# ('stopped', 'stop')
# ('because', 'becaues')
# ('Lead', 'Led')
# ('nipped', 'niped')
# ('corner', 'croner')
# ('lorry', 'lory')
# ('proceeded', 'proceded')
# ('half past', 'harfparst')
# ('three', 'thee')
# ('lorry', 'lory')
# ('Meanwhile', 'Mean while')
# ('James', 'Jame')
# ('James', 'Jame')
# ('to', 'too')
# ('James', 'Jame')
# ('James', 'Jame')
# ('lorry', 'lory')
# ('James', 'Jame')
# ('James', 'Jame')
# ('lie', 'liy')
# ('James', 'Jame')
# ('interned', 'intended')
# ('double', 'doudle')
# ('James', 'Jame')
# ('notes', 'nots')
# ('James', 'Jame')
# ("That's", 'Thats')
# ('James', 'Jame')
# ('knocked', 'knokt')
# ('friends', 'frends')
# ('picked', 'pick')
# ('realized', 'realise')
# ('told', 'toled')
# ('gang', 'ganer')
# ('James', 'Jame')
# ('friend', 'frend')
# ('off', 'of')
# ('lying', 'laying')
# ('heap', 'heep')
# ('floor', 'flor')
# ('stopped', 'stop')
# ('knocked', 'know')
# ('knocked', 'know')
# ('friends', 'frends')
# ('looked', 'look')
# ('front', 'frunt')
# ('James', 'Jame')
# ('coming', 'come')
# ('stairs', 'sters')
# ('police', 'polic')
# ('caught', 'cought')
# ('James', 'Jame')
# ('friends', 'frends')
# ('got', 'go')
# ('tramp', 'tamp')
# ('walking', 'warking')
# ('freezing', 'frizing')
# ('hard', 'had')
# ('from', 'for')
# ('gutter', 'guter')
# ('houses', 'houes')
# ('snow', 'snowe')
# ('crisp', 'cresp')
# ('walked', 'wark')
# ('saw', 'sorw')
# ('from', 'for')
# ('ditch', 'dich')
# ('walked', 'wark')
# ('towards', 'towords')
# ('arrived', 'arived')
# ('barn', 'bran')
# ('heap', 'heep')
# ('straw', 'strow')
# ('heap', 'heep')
# ('potatoes', 'potates')
# ('locker', 'loker')
# ('walked', 'wark')
# ('straw', 'storw')
# ('thought', 'throught')
# ('better', 'beter')
# ('empty', 'emty')
# ('handed', 'hang')
# ("farmer's", 'farmers')
# ('rabbits', 'rabbit')
# ('some', 'sum')
# ('potatoes', 'potates')
# ('walked', 'warked')
# ("Tom's", 'Toms')
# ('ache', 'ack')
# ('stopped', 'stoped')
# ('brussels', 'brus')
# ('getting', 'get')
# ('put', 'pot')
# ('thought', 'thot')
# ('looked', 'look')
# ('saw', 'sow')
# ('walked', 'warked')
# ('some', 'somes')
# ('diesel', 'disel')
# ('lose', 'los')
# ('hedge', 'heg')
# ('fire', 'fre')
# ('brussels', 'brusels')
# ('old', 'ol')
# ('brussels', 'brusls')
# ('also', 'allso')
# ('enjoyed', 'injoid')
# ('farmer', 'farm')
# ('waiting', 'wating')
# ('farmer', 'farm')
# ('thief', 'thif')
# ('farmer', 'farm')
# ('alright', 'allright')
# ("don't", 'dont')
# ('farmer', 'farm')
# ('climbed', 'cimed')
# ('want', 'wont')
# ('farmer', 'farm')
# ('before', 'befor')
# ('farmer', 'farm')
# ('?', 'grow')
# ('off', 'of')
# ('walked', 'warked')
# ('barn', 'bran')
# ('brussels', 'brust')
# ('one', 'on')
# ('America', 'American')
# ('brakes', 'breaks')
# ('ambulance', 'amblance')
# ('injuries', 'injurys')
# ('ambulance', 'amblance')
# ('dying', 'dieing')
# ('gave', 'cave')
# ('save', 'safe')
# ('put', 'but')
# ('jogged', 'joged')
# ('ground', 'grouned')
# ('candlestick', 'candle stick')
# ('himself', 'him  self')
# ('Two', 'Tow')
# ("man's", 'mans')
# ('cupboard', 'cobard')
# ('shoot', 'shot')
# ('please', 'pleace')
# ("don't", 'dont')
# ('neighbour', 'nabour')
# ('heard', 'heared')
# ("John's", 'johns')
# ('boys', "boy's")
# ('apple', 'apply')
# ('coming', 'comeing')
# ('wiped', 'wippd')
# ('bending', 'bend in')
# ('their', 'thire')
# ("I've", 'Ive')
# ('their', 'there')
# ('garage', 'carage')
# ('yankee', 'yanky')
# ('off', 'of')
# ('about', 'a bout')
# ('pictures', 'pitures')
# ('tonight', 'to night')
# ('alright', 'orrigh')
# ('pictures', 'pitures')
# ('cinema', 'cinma')
# ('their', 'there')
# ('along', 'a long')
# ('straight', 'stright')
# ('alright', 'orright')
# ("I'll", 'Ill')
# ('ninety', 'ninty')
# ('steering', 'stearing')
# ('straight', 'stright')
# ('through', 'throw')
# ('people', 'pople')
# ('too', 'to')
# ('anything', 'anyting')
# ("peter's", 'peters')
# ('ambulance', 'amblance')
# ('crowd', 'croud')
# ("don't", 'dont')
# ('their', 'there')
# ('their', 'there')
# ('bodies', 'bodys')
# ('to', 'the')
# ('buried', 'bered')
# ('their', 'there')
# ("parent's", 'parents')
# ('too', 'to')
# ('funeral', 'funrel')
# ('took', 'too')
# ("peter's", 'peters')
# ('fainted', 'fanded')
# ('grave', 'crave')
# ('her', 'here')
# ('coffins', 'cofens')
# ('grave', 'crave')
# ("peter's", 'peter')
# ('her', 'here')
# ('heartbreak', 'hertbreake')
# ("Jane's", 'Janes')
# ('attend', 'atened')
# ('funeral', 'funerl')
# ('heard', 'hered')
# ('funeral', 'funerl')
# ('weeping', 'weping')
# ('honeymoon', 'honymoon')
# ("peter's", 'peters')
# ("don't", 'dont')
# ('yourself', 'your self')
# ('kept', 'kep')
# ('their', 'there')
# ('daughter', 'dauter')
# ("peter's", 'peters')
# ('heart', 'hart')
# ('attack', 'atack')
# ("peter's", 'peters')
# ('loneliest', 'lonlest')
# ("peter's", 'peters')
# ("peter's", 'peter')
# ('Italy', 'Itlay')
# ('soon', 'son')
# ("peter's", 'peters')
# ('Father', 'Farther')
# ('Stuart', 'Sturt')
# ('Geoff', 'Goef')
# ('nearly', 'nely')
# ('anyone', 'any own')
# ('full', 'ful')
# ('saw', 'soor')
# ('meadow', 'meddow')
# ('said', 'seid')
# ('head', 'hed')
# ('to', 'too')
# ('myself', 'my self')
# ("that's", 'thats')
# ('leave', 'leav')
# ('weekends', 'weekend')
# ('There', 'They')
# ('heifer', 'effer')
# ('again', 'a gain')
# ('to', 'too')
# ('field', 'fild')
# ('uncovered', 'an cafferd')
# ('mangels', 'manggles')
# ('loads', 'loades')
# ("o'clock", 'oclock')
# ('another', 'a nother')
# ('four', 'for')
# ('loads', 'loades')
# ('got', 'go')
# ('that', 'theat')
# ('which', 'witch')
# ('weekends', 'week ends')
# ('geared', 'gird')
# ('forward', 'fowd')
# ('gears', 'girse')
# ('reverse', 'reveirse')
# ('four', 'for')
# ('cylinders', 'silinders')
# ('hydraulic', 'high drollit')
# ('manifold', 'many fold')
# ('has', 'as')
# ('bottom', 'botton')
# ('radiator', 'radyator')
# ('because', 'becouse')
# ('at all', 'a tall')
# ('her', 'here')
# ('her', 'here')
# ('her', 'here')
# ('does', 'dus')
# ('at all', 'a tool')
# ('her', 'here')
# ("don't", 'dont')
# ('girl', 'gell')
# ('bran', 'brain')
# ('there', 'their')
# ('trouble', 'truble')
# ('bran', 'brain')
# ('her', 'here')
# ("couldn't", 'couldnt')
# ('thanks', 'thank')
# ("that's", 'thats')
# ("isn't", "in'sen't")
# ('yes', 'yess')
# ('should', 'sould')
# ('know', 'no')
# ('want', "won't")
# ('want', "won't")
# ('her', 'here')
# ('her', 'here')
# ("Jones's", 'Joneses')
# ('workmen', 'work men')
# ('turn', 'tern')
# ('help', 'held')
# ('her', 'here')
# ('her', 'here')
# ('her', 'here')
# ('for', 'fore')
# ('too', 'to')
# ('alive', 'alife')
# ('weighed', 'wade')
# ('someone', 'some one')
# ('grieve', 'greive')
# ('shall', 'she')
# ('never', 'nether')
# ('clothes', 'cloths')
# ('covered', 'coverd')
# ('nearly', 'niely')
# ('were', 'where')
# ('lorries', "lorry's")
# ('ran', 'run')
# ('straight', 'strate')
# ('more', 'moor')
# ('shy', 'shiy')
# ('hallo', 'halloe')
# ('hallo', 'alloe')
# ('where', 'were')
# ('right', 'rigth')
# ("isn't it", 'isinted')
# ('want', 'whon')
# ("don't", 'dont')
# ('hope', 'hop')
# ('right', 'rigth')
# ('something', 'sothing')
# ('always', 'allways')
# ('what', 'whot')
# ('for', 'fore')
# ('instance', 'instace')
# ('cuddling', 'cuddly')
# ('said', 'siad')
# ("don't", 'dont')
# ("don't", 'dont')
# ('want', 'whant')
# ('alright', 'arigth')
# ('feel', 'feal')
# ('feeling', 'feling')
# ('again', 'agian')
# ('audrey', 'audre')
# ('introduced', 'interdust')
# ('audrey', 'audre')
# ('audrey', 'audre')
# ('audrey', 'audre')
# ('meet', 'me')
# ('picture', 'pictuou')
# ('like', 'lik')
# ('oh', 'ow')
# ('called', 'could')
# ('thieves', 'theves')
# ('liked', 'lick')
# ('oldest', 'olddis')
# ('drain', 'drian')
# ('Audrey', 'audre')
# ('oh', 'ow')
# ("wasn't", 'wastent')
# ('funny', 'funney')
# ('thought', 'thorugh')
# ('his', 'is')
# ('friend', 'frend')
# ('policeman', 'police man')
# ('best', 'beets')
# ('Oh', 'Ow')
# ('tonight', 'to nigth')
# ('oh', 'ow')
# ('might', 'migth')
# ('might', 'migth')
# ('an', 'a')
# ('just', 'gust')
# ("doesn't", 'doesnet')
# ('flick', 'fick')
# ('off', 'of')
# ('want', 'whont')
# ('just', 'gust')
# ('teeth', 'theeat')
# ('taste', 'tast')
# ('juicy', 'juiciy')
# ('feel', 'feal')
# ('makes', 'mack')
# ('gay', 'jay')
# ('wonderful', 'wondoful')
# ('there', 'their')
# ('us', 'use')
# ('tonight', 'tonigth')
# ('just', 'gust')
# ("doesn't", 'donsent')
# ('matter', 'mater')
# ("needn't", 'needent')
# ('oh', 'ow')
# ('It', 'I')
# ('suppose', 'sopose')
# ('ready', 'redey')
# ('tonight', 'to nigth')
# ('used', 'ust')
# ('have', 'of')
# ('have', 'of')
# ('dumb', 'doum')
# ('paralysed', 'paralised')
# ('sometimes', 'sone theme')
# ('cries', 'crys')
# ('gets', 'get')
# ('nerves', 'nerve')
# ('doing', 'dowing')
# ('nuisance', 'nousant')
# ('keeps', 'keep')
# ('kicking', 'kiging')
# ("can't", 'canth')
# ('really', 'reley')
# ('thomas', 'thomes')
# ('party', 'partey')
# ("didn't", 'didden')
# ('watching', 'watcheing')
# ('someone', 'some one')
# ('asked', 'ask')
# ('join', 'goin')
# ('girls', 'girl')
# ('asked', 'ask')
# ('join', 'joine')
# ('awful', 'alfull')
# ('talk', 'torck')
# ('tell', 'teel')
# ("isn't", 'isant')
# ('make-up', 'macke up')
# ('teaches', 'teset')
# ('lovely', 'lovyley')
# ('looked', 'look')
# ('wet', 'weat')
# ('brought', 'broug')
# ('step', 'stepe')
# ('baby', 'babby')
# ('whose', 'hows')
# ("I'll", 'ill')
# ('police', 'poilice')
# ('might', 'mite')
# ('hungry', 'hungrey')
# ('likes', 'like')
# ("I'll", 'I')
# ('street', 'sterret')
# ('there', 'their')
# ('picked', 'pick')
# ('its', 'it')
# ('trap', 'crat')
# ('broken', 'brocken')
# ('it', 'is')
# ('built', 'bilt')
# ('hutch', 'hudge')
# ('tried', 'trid')
# ('found', 'fed')
# ('female', 'feemale')
# ('not', 'no')
# ('fight', 'figth')
# ('months', 'month')
# ('babies', 'babyes')
# ('four', 'fore')
# ('little', 'litte')
# ('never', 'neve')
# ('wanted', 'wonted')
# ('leave', 'leve')
# ('hutch', 'hudge')
# ('built', 'buit')
# ('breadcrumbs', 'bred crumes')
# ('ate', 'eat')
# ('much', 'mush')
# ('lived', 'live')
# ('hutch', 'hudge')
# ('until', 'uatill')
# ('died', 'diad')
# ('story', 'sory')
# ('Holiday', 'Holliday')
# ("isn't", 'isten')
# ('insects', 'insexs')
# ('frogspawn', 'frogsporn')
# ('every', 'evry')
# ('die', 'diy')
# ('It', 'I')
# ('hard', 'had')
# ('spawn', 'sporn')
# ('underneath', 'under nethe')
# ('takes', 'thak')
# ('months', 'monsth')
# ('?', 'hast')
# ('fins', 'finse')
# ('there', 'their')
# ("wasn't", "whan't")
# ('many', 'meay')
# ('first', 'fast')
# ("weren't", 'whernt')
# ('near', 'nere')
# ('white', 'withe')
# ('only', 'ony')
# ('picked', 'piked')
# ('them', 'then')
# ('jar', 'gare')
# ('large', 'larg')
# ('jar', 'gare')
# ('otherwise', 'other wise')
# ('tadpoles', 'tadpolls')
# ('grow', 'grows')
# ('much', 'mush')
# ('spawn', 'sporn')
# ('climb', 'clime')
# ('tip', 'tope')
# ('frogs', 'rogs')
# ('just', 'gust')
# ('watch', 'wash')
# ('It', 'I')
# ('tip', 'tiper')
# ('frogs', 'frog')
# ('just', 'gust')
# ('lose', 'loos')
# ('they', 'there')
# ('clean', 'glean')
# ('and', 'hand')
# ('their', 'there')
# ('weed', 'wead')
# ('chew', 'chow')
# ('swirling', 'swaling')
# ('refreshing', 'refection')
# ('until', 'untill')
# ('kept', 'keept')
# ('staring', 'stearing')
# ('letter', 'teller')
# ('until', 'untill')
# ('someone', 'some one')
# ('noise', 'nose')
# ('came', 'cam')
# ('dream', 'drem')
# ('there', 'their')
# ('breeze', 'breez')
# ('until', 'untill')
# ('feel', 'feal')
# ('breeze', 'breez')
# ('dark', 'darck')
# ('to', 'the')
# ('sleepy', 'sleepey')
# ('closed', 'closd')
# ('opened', 'open')
# ('different', 'difrent')
# ('from', 'form')
# ('upon', 'apone')
# ('gate', 'gait')
# ('snooty', 'snoty')
# ('Oh', 'Ow')
# ('no', 'now')
# ('alright', 'aright')
# ('what', 'wath')
# ('It', 'I')
# ('back', 'bake')
# ("won't", 'wont')
# ('time', 'thim')
# ('the', 'th')
# ('biscuits', 'biccuits')
# ("you'll", 'you')
# ('trouble', 'trobel')
# ('much', 'mush')
# ('?', 'wild')
# ('on', 'of')
# ('your', 'you')
# ('closed', 'clous')
# ('hear', 'here')
# ('talk', 'tork')
# ('rustle', 'rusall')
# ('feel', 'feal')
# ('bare', 'bear')
# ('has', 'hase')
# ('gone', 'go')
# ('clouds', 'couldes')
# ('everyone', 'evry on')
# ('starts', 'starst')
# ("there's", 'there')
# ('their', 'there')
# ('together', ' to gether')
# ('storms', 'stormes')
# ('became', 'bacam')
# ('towel', 'towe')
# ('clouds', 'coulds')
# ('dreaming', 'dreming')
# ('mystery', 'mistory')
# ('castle', 'catsal')
# ('selfish', 'slevish')
# ('they', 'the')
# ('heard', 'herd')
# ('castle', 'catal')
# ('middle', 'midal')
# ('lake', 'lack')
# ('decided', 'disided')
# ('explore', 'expore')
# ('they', 'the')
# ('borrowed', 'borrowd')
# ('sailed', 'saled')
# ('lake', 'lack')
# ('near', 'nere')
# ('castle', ' cartsel')
# ('saw', 'sor')
# ('signpost', 'sine post')
# ('beware', 'bewere')
# ('castle', 'cartal')
# ('there', 'ther')
# ('horrid', 'horid')
# ('witch', 'wiche')
# ('about', 'a bout')
# ('signpost', 'sine post')
# ('nearer', 'nerer')
# ('castle', 'carlsat')
# ('signpost', 'sing post')
# ('which', 'wich')
# ("didn't", 'dident')
# ('four', 'fore')
# ('mask', 'marsk')
# ('their', 'there')
# ('four', 'for')
# ('spy', 'spiy')
# ('knew', 'now')
# ('mystery', 'mistory')
# ('castle', 'cartal')
# ('girls', 'gerls')
# ('what', 'wate')
# ('rowed', 'rowd')
# ('until', 'untill')
# ('one', 'on')
# ('disappeared', 'disaperd')
# ('wondered', 'wonder')
# ('where', 'were')
# ('gone', 'gon')
# ('bubbles', 'bubbals')
# ('lake', 'lack')
# ('knew', 'now')
# ('where', 'were')
# ('at', 'are')
# ('lake', 'lack')
# ('trying', 'tring')
# ('there', 'ther')
# ('before', 'befor')
# ('there', 'ther')
# ('plan', 'play')
# ('castle', 'cartill')
# ('where', 'were')
# ('can', 'cane')
# ('explore', 'expore')
# ('castle', 'carsell')
# ('ourselves', 'and selve')
# ('there', 'their')
# ('hidden', 'hidon')
# ('treasure', 'tresure')
# ('richer', 'recher')
# ("month's", 'month')
# ('Switzerland', 'Swizaland')
# ("needn't", 'nedent')
# ('until', 'untill')
# ('booze', 'bouse')
# ('shut up', 'shock')
# ('hear', 'her')
# ('fool', 'full')
# ('yourself', 'your sleve')
# ("you're", 'your')
# ('much', 'mush')
# ('noise', 'nose')
# ('someone', 'some one')
# ('heard', 'herd')
# ('otherwise', 'other wise')
# ("they'll", 'theile')
# ('something', 'somethick')
# ('fishy', 'fishey')
# ('alright', 'arigh')
# ('will', "we'll")
# ('knew', 'now')
# ('they', 'the')
# ('carried', 'carrid')
# ('went', 'whent')
# ('lake', 'lack')
# ('knew', 'nowe')
# ('gear', 'gere')
# ("didn't", 'dind')
# ('signpost', 'sine post')
# ('looked', 'look')
# ('great', 'grait')
# ('lightning', 'ligthing')
# ('lake', 'lack')
# ('rough', 'rougth')
# ('dangerous', 'dangerus')
# ('frightened', 'frigtend')
# ('tipped', 'tipe')
# ('over', 'overy')
# ('drowned', 'dround')
# ('treasure', 'thresher')
# ('nor', 'nore')
# ('rumour', 'rumer')
# ('castle', 'carsal')
# ('mystery', 'mistory')
# ('years', 'yers')
# ('no one', 'know on')
# ('knew', 'now')
# ('four', 'fore')
# ('explored', 'expord')
# ('went', 'whent')
# ("weren't", "wern't")
# ('anything', 'anythink')
# ('witch', 'wich')
# ('mystery', 'mistory')
# ('towers', 'tower')
# ('there', 'their')
# ('crawling', 'crowling')
# ('frightened', 'frightend')
# ('creepy', 'crepy')
# ('locked', 'lock')
# ('picked', 'pick')
# ('the', 'they')
# ('opened', 'open')
# ('bravest', 'bravist')
# ('one', 'on')
# ('dared', 'dere')
# ('stiff', 'stive')
# ('grated', 'grete')
# ('opened', 'open')
# ('horrified', 'horrieyfide')
# ('someone', 'some on')
# ('one', 'on')
# ('girls', 'girl')
# ('near', 'nere')
# ('saw', 'sore')
# ('witch', 'wich')
# ('nearly', 'nerly')
# ('girls', 'girl')
# ('there', 'their')
# ('disturb', 'distrebe')
# ('anyone', 'any on')
# ('souvenir', 'suvenere')
# ('mystery', 'mistory')
# ('there', 'their')
# ('Jones', 'Johnes')
# ('no one', 'know one')
# ('knows', 'knowes')
# ('washed', 'wosh')
# ("children's", 'childrenes')
# ('hair', 'hire')
# ('grocer', 'grouser')
# ('brought', 'brough')
# ('fruit', 'frit')
# ('back', 'bake')
# ('talked', 'tork')
# ('a while', 'awill')
# ('called', 'calld')
# ('death', 'deat')
# ('laughing', 'lauging')
# ('decided', 'desided')
# ('herself', 'he slef')
# ('middle', 'middal')
# ('unconscious', 'uncoshers')
# ('miring', 'morning')
# ('sound', 'sownd')
# ('no', 'know')
# ('reply', 'replie')
# ('worried', 'worid')
# ('somewhere', 'some were')
# ('phoned', 'phone')
# ('ambulance', 'amberless')
# ('her', 'he')
# ('Nicholls', 'Nickals')
# ("we'll", 'will')
# ('take', 'thak')
# ("they'll", 'their')
# ('matter', 'mater')
# ('rushed', 'rust')
# ('there', 'their')
# ('they', 'the')
# ("hadn't", 'hadnt')
# ('there', 'their')
# ('went', 'when')
# ('ambulance', 'amerless')
# ('stayed', 'stayd')
# ('waited', 'whated')
# ("o'clock", 'o clock')
# ('the', 'they')
# ('everyone', 'every one')
# ('stayed', 'stad')
# ('friends', 'freinds')
# ('week', 'weeke')
# ('married', 'marrid')
# ('getting', 'geting')
# ('alright', 'arigth')
# ('want', "won't")
# ('marge', 'marg')
# ('please', 'pleas')
# ('said', 'siad')
# ('morning', 'moning')
# ('please', 'pleas')
# ('what', "wha't")
# ('noise', 'nose')
# ('Someone', 'Some one')
# ('tape', 'tipped')
# ('what', "wha't")
# ('who', 'how')
# ('taken', 'tackon')
# ('stolen', 'stowlen')
# ('found', 'fond')
# ('ditch', 'dich')
# ('mine', 'my')
# ('there', 'their')
# ('worry', 'worye')
# ('policeman', 'police man')
# ('asked', 'ask')
# ('what', "wha't")
# ('happened', 'happon')
# ('stolen', 'stowlen')
# ('please', 'pleas')
# ('there', 'their')
# ('too', 'to')
# ('lately', 'latley')
# ('babies', 'babyes')
# ('being', 'been')
# ('stolen', 'stowlen')
# ('killed', 'killd')
# ('want', "whan't")
# ('want', "whan't")
# ('doing', 'dowing')
# ('worried', 'worred')
# ('nervous', 'nerves')
# ('threw', 'through')
# ('happened', 'happen')
# ('Oh', 'Ow')
# ('crikey', 'crigckey')
# ("there's", 'theres')
# ('policeman', 'police man')
# ('outside', 'out side')
# ('pavement', 'pathment')
# ('what', "wha't")
# ('know', 'now')
# ('basket', 'barscket')
# ('clothes', 'clous')
# ('know', 'now')
# ('off', 'of')
# ('ordinary', 'ordenrey')
# ('know', 'now')
# ('what', "wha't")
# ('basket', 'baskek')
# ('take', 'thack')
# ('laundry', 'lordery')
# ('What', "Wh't")
# ('shuffling', 'shufarling')
# ('basket', 'basckek')
# ('please', 'pleas')
# ("you're", 'your')
# ('see', 'se')
# ('what', "wha't")
# ("you're", 'your')
# ('hear', 'here')
# ('stole', 'stowl')
# ('policeman', 'police man')
# ('blew', 'blow')
# ('whistle', 'wiscell')
# ('policemen', 'police men')
# ('far', 'fare')
# ('before', 'befor')
# ('policeman', 'police man')
# ('caught', 'cought')
# ('struggled', 'strogald')
# ('a bit', 'abit')
# ('calmed', 'carmd')
# ('station', 'stastione')
# ('statement', 'statmeant')
# ('jail', 'jaell')
# ('two', 'to')
# ('babies', 'babyis')
# ('lady', 'ladys')
# ('whose', 'who')
# ('stolen', 'stowle')
# ('safely', 'safaly')
# ('draw', 'drew')
# ('Bang', 'Bankg')
# ('straight', 'staidght')
# ('Bang', 'Bankg')
# ('Bang', 'Bankg')
# ('Bang', 'Bankg')
# ('your', 'yor')
# ('there', 'thre')
# ('myself', 'my self')
# ('dad', 'bad')
# ('My', 'By')
# ('dad', 'bad')
# ('electrician', 'elecenician')
# ('does', 'dus')
# ('housework', 'housee work')
# ('nearly', 'kneeling')
# ('Which', 'Wiich')
# ('Note', 'Noet')
# ('wait', 'weight')
# ('minutes', 'mine')
# ('with', 'wiht')
# ('two', 'to')
# ('policemen', 'policeman')
# ("man's", 'man')
# ('friend', 'fenird')
# ("Dog's", 'Dog')
# ('friend', 'fenird')
# ('body', 'bod')
# ('too', 'to')
# ('dirty', 'driy')
# ('too', 'to')
# ('another', 'a nother')
# ('woman', 'womon')
# ('Kidneys', 'Kidney')
# ('ate', 'eat')
# ('killed', 'kill')
# ('kidneys', 'kidney')
# ('ate', 'eat')
# ('had', 'hab')
# ('two', 'to')
# ('woman', 'wamon')
# ('killed', 'kill')
# ('Next', 'Nexe')
# ('marshland', 'marshladn')
# ('footprints', 'foodprints')
# ('Factory', 'Facttoer')
# ('coming', 'comeing')
# ('went', 'wet')
# ('on', 'hon')
# ('some', 'shm')
# ('captain', 'captman')
# ('took', 'thc')
# ('us', 'hus')
# ('out', 'hot')
# ('on', 'hn')
# ('our', 'out')
# ('went', 'wet')
# ('on', 'hon')
# ('was', 'wos')
# ('went', 'wet')
# ('captain', 'catptman')
# ('motor-cruiser', 'motor-cruisr')
# ('on', 'hon')
# ('told', 'tod')
# ('told', 'tod')
# ('disposal', 'disposol')
# ('they', 'thror')
# ('they', 'thrar')
# ('put', 'pht')
# ("Frogmen's", 'Frgmens')
# ('went', 'wet')
# ('there', 'thaw')
# ('for', 'fo')
# ('they', 'thrar')
# ('chain', 'choin')
# ('held', 'hasld')
# ('they', 'thrar')
# ('horns', 'horn')
# ('it', 'hit')
# ('went', 'wit')
# ('boy', 'buy')
# ('heard', 'her')
# ('his', 'is')
# ('run away', 'runaway')
# ('uncle', 'unlce')
# ('Southwold', 'Suothwode')
# ('orphaned', 'orphaed')
# ('there', 'thrar')
# ('Boys', 'Boy')
# ('Boys', 'Boy')
# ('went', 'wnet')
# ('play', 'payer')
# ('made', 'mayd')
# ('den', 'dener')
# ('Fire', 'Fiyer')
# ('Farmer', 'Frameman')
# ('gun', 'gon')
# ('fired', 'fiyed')
# ('hit', 'hiter')
# ('Boys', 'Boy')
# ('orphaned', 'ophoned')
# ('beat', 'pit')
# ('him', 'im')
# ('went', 'wet')
# ('?', 'Doc chm')
# ('shot', 'sot')
# ('was', 'wos')
# ('alright', 'or rit')
# ('END', 'HED')
# ('from', 'fom')
# ('saw', 'sor')
# ('door', 'dor')
# ('opened', 'oped')
# ('walked', 'wocer')
# ('went', 'wend')
# ('downstairs', 'dau sosys')
# ('saw', 'sor')
# ('hole', 'holler')
# ('?', 'saffrery')
# ('went', 'wet')
# ('over', 'hover')
# ('found', 'feod')
# ('?', 'pelser')
# ('the', 'thoy')
# ('?', 'cHmer')
# ('END', 'EDH')
# ('cinema', 'cinama')
# ('cinema', 'cinama')
# ('off', 'of')
# ('boyfriend', 'boyfreind')
# ('alone', 'a lone')
# ('cinema', 'cinama')
# ('engaged', 'ingaged')
# ('engaged', 'ingaged')
# ("o'clock", 'oclock')
# ('said', 'siad')
# ('their', 'there')
# ('amusements', 'amusments')
# ('amusements', 'amusments')
# ('said', 'siad')
# ("let's", 'lets')
# ("o'clock", 'oclock')
# ('unexpected', 'unispected')
# ('comfortable', 'comvatable')
# ('crapped', 'crept')
# ('lay', 'laid')
# ('here', 'hear')
# ('crept', 'creeped')
# ('captain', 'captian')
# ('aboard', 'abroard')
# ("I'll", 'ile')
# ('off', 'of')
# ("don't", 'dont')
# ('home', 'hime')
# ("don't", 'dont')
# ("it's", 'its')
# ("it's", 'its')
# ('runway', 'runaway')
# ('its', 'is')
# ("it's", 'its')
# ('lying', 'laying')
# ("it's", 'its')
# ('there', 'the')
# ('dump', 'pump')
# ('two', 'to')
# ('girlfriends', 'girlfriend')
# ('and', 'an')
# ('bicycles', 'bciyle')
# ('brother', 'borther')
# ('got', 'go')
# ('there', 'ther')
# ('bedrooms', 'bed room')
# ('got', 'go')
# ('player', 'playa')
# ('looking', 'look')
# ('his', 'is')
# ('his', 'is')
# ('his', 'is')
# ('eyes', 'eye')
# ('department', 'depatment')
# ('looks', 'look')
# ('Pleased', 'Please')
# ('starts', 'start')
# ('tomorrow', 'to morrow')
# ('his', 'is')
# ('morning', 'morring')
# ('comes', 'come')
# ('gets', 'get')
# ('gets', 'get')
# ('ready', 'realy')
# ('got', 'go')
# ('at', 'are')
# ('gets', 'get')
# ('Boss', 'Bos')
# ('something', 'some thing')
# ('to', 'the')
# ('them', 'then')
# ('got', 'go')
# ('police', 'poicle')
# ('police', 'poicle')
# ('there', 'ther')
# ('police', 'poicle')
# ('got', 'go')
# ('boss', 'bos')
# ('lorry', 'lord')
# ('department', 'departent')
# ('snakes', 'snake')
# ('his', 'is')
# ("don't", 'dont')
# ('sees', 'see')
# ('playing', 'play')
# ('picked', 'pick')
# ('away', 'a way')
# ('shouting', 'shout')
# ("boy's", 'boy')
# ('her', 'there')
# ('running', 'run')
# ('where', 'were')
# ("don't", 'don')
# ('know', 'on')
# ('off', 'of')
# ('get', 'gett')
# ('men', 'man')
# ('search', 'seach')
# ('for', 'of')
# ('looked', 'look')
# ('everywhere', 'evry were')
# ('found', 'find')
# ("boy's", 'boy')
# ('can', 'cane')
# ('his', 'is')
# ('no', 'on')
# ("won't", 'won')
# ('when', 'went')
# ('here', 'hear')
# ('as', 'has')
# ('alley', 'ally')
# ('jumped', 'jump')
# ('on', 'one')
# ('anyone', 'any one')
# ('jumped', 'jump')
# ('his', 'is')
# ('switched', 'switch')
# ('off', 'of')
# ('no one', 'not one')
# ('missed', 'miss')
# ('boys', 'boy')
# ('ran', 'run')
# ('tree', 'three')
# ('suddenly', 'senddly')
# ('shouted', 'shout')
# ('here', 'hear')
# ('here', 'hear')
# ('coming', 'come')
# ('go', 'got')
# ('without', 'with out')
# ('stopped', 'stop')
# ('weeks', 'week')
# ('opened', 'opon')
# ('off', 'of')
# ('called', 'call')
# ('belongs', 'belong')
# ("ripper's", 'ripper')
# ('looked', 'look')
# ('looked', 'look')
# ('everywhere', 'every were')
# ('got', 'go')
# ('looked', 'look')
# ('knocked', 'knock')
# ('gone', 'go')
# ('goes', 'go')
# ('after', 'half')
# ('got', 'go')
# ('alley', 'ally')
# ('could', 'call')
# ('he', 'ther')
# ('charged', 'change')
# ('years', 'year')
# ('ago', 'a go')
# ('pay', 'paid')
# ('nights', 'night')
# ('Stanley', 'Stanlay')
# ('drives', 'drive')
# ('steak', 'stack')
# ('steak', 'stack')
# ('stewing', 'stawing')
# ('steak', 'stack')
# ('beef', 'bf')
# ('where', 'were')
# ('when', 'went')
# ('nights', 'night')
# ('too', 'to')
# ('friends', 'frend')
# ('Tommy', 'Tomy')
# ('an', 'and')
# ('got', 'go')
# ('push-bicycle', 'pusbycile')
# ('going', 'go')
# ('tonight', 'to night')
# ('got', 'go')
# ('at', 'a')
# ('her', 'he')
# ("what's", 'whats')
# ('splendid', 'splended')
# ("you're", 'your')
# ('too', 'to')
# ("o'clock", 'oclock')
# ("what's", 'whats')
# ('tomorrow', 'tommorrow')
# ("we're", 'were')
# ("let's", 'lets')
# ("there's", 'theres')
# ("let's", 'lets')
# ('too', 'to')
# ("Let's", 'Lets')
# ('shining', 'shinning')
# ('go', 'got')
# ('want', 'wand')
# ('wavy', 'wavey')
# ('his', "he's")
# ('postcards', 'post cards')
# ("days'", "day's")
# ("weren't", "were'nt")
# ('nurses', "nurse's")
# ('their', 'there')
# ('my', 'may')
# ("daddy's", 'dadies')
# ('taking', 'takeing')
# ("it's", 'its')
# ('Comment allez-vous', 'Comatalevous')
# ('Comment allez-vous', 'Comatalevous')
# ('monsieur', 'missiour')
# ('senor', 'senour')
# ('pretty', 'preety')
# ('prettiest', 'pretiest')
# ('private', 'privait')
# ('secretary', 'secutery')
# ("o'clock", 'oclock')
# ("o'clock", 'oclock')
# ('evening', 'evning')
# ('lived', 'live')
# ('away', 'a way')
# ('married', 'marreid')
# ('the', 'thee')
# ('run', 'ran')
# ("o'clock", 'oclock')
# ('anything', 'anythink')
# ('registry', 'registery')
# ('they', 'the')
# ('celebrated', 'celebrate')
# ("o'clock", 'oclock')
# ('his', 'he')
# ("that's", 'thats')
# ('your', 'youre')
# ('yes', 'yet')
# ('think', 'thing')
# ('waggon', 'wagon')
# ('indian', 'inded')
# ('waggon', 'wagon')
# ('waggon', 'wagon')
# ('Lone', 'Long')
# ('Ranger', 'Rango')
# ('knit', 'knitt')
# ('photo', 'phto')
# ('cannot', 'connot')
# ("let's", 'lets')
# ('christmas', 'christman')
# ('beautiful', 'beaufiful')
# ('be', 'by')
# ('displaying', 'dispiaying')
# ('nearest', 'nearst')
# ('says', 'say')
# ('yourself', 'yourseff')
# ('Thinking', 'Thinkng')
# ('few', 'faw')
# ('sooner', 'sonner')
# ('sex', 'ses')
# ('gives', 'give')
# ('sexual', 'exual')
# ('stimulated', 'simulated')
# ('principle', 'principl')
# ('policeman', 'policman')
# ('for', 'fur')
# ('comes', 'come')
# ('telephoned', 'telephone')
# ('there', 'he')
# ('character', 'characte')
# ('screen', 'seveen')
# ('enjoys', 'enyays')
# ('possess', 'passess')
# ('vernacular', 'veracular')
# ('nearly', 'neally')
# ('outfit', 'out fit')
# ('Once', 'Ones')
# ('upon', 'apen')
# ('downstairs', 'down stairs')
# ('watch', 'wacth')
# ('what', 'whats')
# ('manager', 'maneger')
# ('said', 'siad')
# ("we'll", 'wel')
# ('yes', 'yess')
# ("I'll", 'Ill')
# ('pictures', 'picture')
# ('got', 'get')
# ('nanny', 'nana')
# ('Every', 'Evey')
# ('every', 'evey')
# ("there's", 'theres')
# ('clothes', 'cloths')
# ('loved', 'love')
# ('Beryl', 'Beryil')
# ('Beryl', 'Beryil')
# ('Beryl', 'Beryil')
# ("there'll", 'therell')
# ("don't", 'dont')
# ('Doctor', 'Docter')
# ('Toby', 'Tobe')
# ("it's", 'its')
# ('single', 'singl')
# ('too', 'to')
# ("haven't", "havn't")
# ('round about', 'roundabout')
# ('disappeared', 'disapeared')
# ('should', 'shoud')
# ("don't", 'dont')
# ('know', 'no')
# ('where', 'were')
# ("doesn't", 'dosnt')
# ("don't", 'dont')
# ('There', 'Ther')
# ('something', 'somthing')
# ('grabbed', 'grabed')
# ('no', 'know')
# ('then', 'they')
# ("couldn't", 'count')
# ('too', 'to')
# ("we'll", 'well')
# ('sometimes', 'some times')
# ('then', 'than')
# ("can't", 'cant')
# ('started', 'startes')
# ('quarrel', 'qurral')
# ('decided', 'desided')
# ('also', 'als')
# ('guided', 'guard')
# ('programme', 'programe')
# ('off', 'of')
# ('told', 'to')
# ('upstairs', 'up stairs')
# ('peeped', 'peped')
# ('outside', 'out side')
# ('kitchen', 'kitchin')
# ("can't", 'cant')
# ('downstairs', 'down stairs')
# ('upstairs', 'up stairs')
# ('listened', 'lisinid')
# ('sometimes', 'sometime')
# ('creeps', 'creaps')
# ("don't", 'dont')
# ('downstairs', 'down stairs')
# ("don't", 'dont')
# ("wasn't", 'wasnt')
# ('upstairs', 'up stairs')
# ('no', 'know')
# ('off', 'of')
# ("that's", 'thats')
# ("don't", 'dont')
# ('suppose', 'surpose')
# ("won't", 'wont')
# ('off', 'of')
# ('really', 'realy')
# ('kissed', 'kiss')
# ('Once', 'Ones')
# ('past', 'pass')
# ('happened', 'happend')
# ("what's", 'whats')
# ('matter', 'mater')
# ("it's", 'its')
# ("it's", 'its')
# ("I'd", 'Id')
# ('fine', 'find')
# ('lamb', 'lam')
# ("aren't", 'arent')
# ("it's", 'its')
# ("I'll", 'Ill')
# ("wasn't", 'wasnt')
# ("let's", 'lets')
# ("I'd", 'Id')
# ("I'll", 'Ill')
# ('stories', 'story')
# ('cried', 'cryed')
# ('babies', 'babys')
# ('Babies', 'Babys')
# ('your', 'you')
# ('dear', 'dead')
# ('stars', 'stare')
# ('COMMENTARY', 'COMENTARY')
# ('Ferrari', 'Farrari')
# ('lead', 'leeding')
# ('leading', 'lead')
# ('Brabham', 'Barham')
# ('Brabham', 'Barham')
# ('Brabham', 'Barham')
# ('through', 'thruogth')
# ('going', 'gying')
# ('Brabham', 'barham')
# ("what's", 'what')
# ('happened', 'heap')
# ('hear', 'haer')
# ('misfiring', 'miss fireing')
# ('Cooper', 'Copper')
# ('Phil Hill', 'Phillhill')
# ('changed', 'cage')
# ('still', 'sill')
# ('here', 'hear')
# ('racing', 'raceing')
# ('still', 'sill')
# ('speaking', 'seking')
# ('quite', 'quit')
# ('crash', 'crush')
# ('here', 'hear')
# ('quit', 'quite')
# ('drivers', 'divers')
# ('behind', 'behed')
# ('killed', 'kill')
# ('their', 'theer')
# ('spectators', 'spectatoes')
# ('engines', 'egreers')
# ('ferrari', 'ferrary')
# ('still', 'sill')
# ('lead', 'led')
# ('April', 'Apirl')
# ('here', 'hear')
# ('April', 'Apirl')
# ('when', 'where')
# ('trees', 'tree')
# ('blossom', 'blossm')
# ('flowers', 'flower')
# ('July', 'Jluy')
# ('months', 'mouth')
# ('reap', 'reper')
# ('nights', 'nigth')
# ('tractor', 'trator')
# ('field', 'feild')
# ('weasel', 'wasel')
# ('gamekeeper', 'gamekeeps')
# ('tree', 'treee')
# ('too', 'to')
# ('cannot', 'can not')
# ('difficult', 'differcult')
# ('difficult', 'differcult')
# ("doesn't", "does'nt")
# ('absolutely', 'absolutly')
# ('concentrate', 'consantrate')
# ('listen', 'listern')
# ('punctuation', 'puntuation')
# ("you're", 'your')
# ('thinking', 'tinking')
# ('takes', 'tacks')
# ('these', 'thoese')
# ('stories', 'story')
# ('should', 'shoold')
# ('form', 'frame')
# ('too', 'to')
# ('be coming', 'became')
# ('our', 'hour')
# ('writing', 'writeing')
# ('heat', 'heart')
# ("girlfriend's", 'girl friend')
# ('fell', 'fall')
# ('once', 'own')
# ("doesn't", 'does on')
# ('getting', 'geting')

# %%
# Extract contexts
n = 3  # Example context window size
contexts = extract_context(text, n)
print("\nContexts:")
for context in contexts:
    print(context)
# Out:
# Contexts:
# ('sister', 'siter', ['Dad', 'Mum', 'and'])
# ('sister', 'siter', ['Tonbury.', 'My', 'Mum'])
# ('goes', 'go', ['out', '.', 'I'])
# ('sometimes', 'some times', ['Tuesday', 'night', 'i'])
# ('sometimes', 'some times', ['Saturdays', 'I', 'go'])
# ('club', 'clob', ['church.', 'I', 'go'])
# ('bellringing', 'bell ringing', ['TV', 'at', '5'])
# ('watch', 'wakh', ['Smallerden.', 'The', 'house'])
# ('front', 'frount', ['do', 'when', 'I'])
# ('second', 'sexeon', ['down', 'the', 'farm'])
# ('watch', 'wach', ['T.V.', 'there', 'is'])
# ('watch', 'wach', ['.', 'The', 'Murder'])
# ('cowboys', 'cow Boys', ['1', 'night', 'when'])
# ('sometimes', 'some times', ['car.', 'The', 'body'])
# ('club', 'colbe', ['man', 'who', 'was'])
# ('watch', 'wach', ['black', 'hair', 'brown'])
# ('watch', 'wach', ['had', 'a', 'lot'])
# ('think', 'thing', ['so', 'they', 'it'])
# ('TV', 'tv', ['murder', 'car.', 'The'])
# ('square', 'squar', ['cars', 'were', 'black'])
# ('eyes', 'iyes', ['one', 'of', 'the'])
# ("o'clock", 'oclock', ['one', 'of', 'the'])
# ('knocked', 'nock', ['day', 'they', 'found'])
# ('at', 'a', ['it', 'he', 'was'])
# ("o'clock", 'oclock', ['kissed', 'a', 'girl'])
# ('killed', 'kild', ['me', 'Of', 'course'])
# ('saw', 'see', ['do', '.', 'It'])
# ('been', 'bean', ['a', 'bell', 'on'])
# ('knocked', 'nock', ['sally.', 'ON', 'the'])
# ('called', 'cald', ['the', 'rope', 'on'])
# ('came', 'cam', ['red', 'white', 'and'])
# ('killed', 'killd', ['Grandsire', 'Triples', 'it'])
# ('there', 'the', ['a', 'long', 'time'])
# ('Her', 'Here', ['I', 'ring', '1'])
# ('eyes', 'iyes', ['and', '3', 'but'])
# ('have to', 'haveto', ['will', 'go', 'up'])
# ('before', 'be for', ['7.30', 'and', 'end'])
# ('anything', 'any thing', ['dad', 'bike', 'to'])
# ('else', 'als', ['SICK', 'SOW', 'OF'])
# ('wheel', 'weel', ['had', 'to', 'go'])
# ('wheel', 'weel', ['because', 'the', 'smell'])
# ('sallies', 'sally', ['came', 'to', 'the'])
# ('others', 'other', ['laid', 'out', 'on'])
# ('rounds', 'rouns', ['my', 'sow', 'we'])
# ('do', 'don', ['some', 'because', 'the'])
# ('ring', 'rings', ['that', 'is', 'only'])
# ('be', 'we', ['sir', 'go', 'and'])
# ('breaks', 'brakes', ['he', 'it', 'to'])
# ('careful', 'carfull', ['while', 'after', 'the'])
# ("Cynthia's", 'Cynthia', ['sir', 'you', 'did'])
# ('gas', 'gass', ['When', 'they', 'are'])
# ('masks', 'marsks', ['you', 'have', 'to'])
# ('floor', 'foor', ['a', 'in', 'with'])
# ('what', 'wat', ['little', 'pigs', 'might'])
# ('gas', 'gass', ['little', 'place', 'off'])
# ('masks', 'marsks', ['only', 'the', 'little'])
# ('too', 'to', ['that', 'is', 'so'])
# ('what', 'wat', ['mother', 'some', 'people'])
# ('wash', 'wosh', ['light', 'in', 'with'])
# ('perhaps', 'prasp', ['you', 'have', 'to'])
# ('ate', 'et', ['mother', 'has', 'a'])
# ('before', 'be for', ['when', 'they', 'eat'])
# ('his', 'is', ['they', 'can', 'some'])
# ('pony', 'poney', ['we', 'give', 'them'])
# ('whiskey', 'wiskey', ['mother', 'you', 'have'])
# ('soap', 'soape', ['away', 'to', 'be'])
# ('whiskey', 'wiskey', ['Billy', 'Bunter', 'was'])
# ('gave', 'cave', ['they', 'sent', 'for'])
# ('gave', 'cave', ['sent', 'Rin', 'Tin'])
# ('got', 'go', ['Barbra', 'Moore', 'Barbra'])
# ('her', 'here', ['sent', 'for', 'Yule'])
# ('her', 'here', ['the', 'sky', 'My'])
# ('soap', 'sope', ['of', 'joy', 'It'])
# ('what', 'wat', ['it', 'might', 'be'])
# ('her', 'here', ['I', 'I', 'would'])
# ('gave', 'cave', ['the', 'Races', 'at'])
# ('whiskey', 'wiskey', ['on', 'my', 'Enfield'])
# ('soap', 'sope', ['go', 'quite', 'this'])
# ('gave', 'cave', ['Enfield', 'there', 'were'])
# ('never', 'knver', ['well', 'I', 'saw'])
# ("that's", 'thats', ['was', 'like', 'mine.'])
# ('killed', 'kild', ['man', 'come', 'off'])
# ('wait', 'wate', ['in', 'Hospital', 'because'])
# ('inject', 'injeck', ['sidecar', 'race', 'I'])
# ('make', 'mack', ['the', 'man', 'was'])
# ('sure', 'shore', ['but', 'the', 'Rider'])
# ('dry', 'drye', ['the', 'crowd', 'I'])
# ('fork', 'falk', ['and', 'down', 'the'])
# ('knock', 'nock', ['who', 'was', 'on'])
# ('themselves', 'them souve', ['down', 'the', 'track'])
# ('them', 'the', ['the', 'went', 'all'])
# ('worm', 'worme', ['the', 'track', 'but'])
# ('powder', 'pouder', ['put', 'it', 'out'])
# ('worm', 'worme', ['on', 'the', 'track'])
# ('get', 'ge', ['Japanese', '1', 'B.S.A.'])
# ('their', 'there', ['line', 'Bang', 'off'])
# ('them', 'theme', ['rest', 'are', 'round'])
# ('keep', 'geep', ['I', 'can', 'see'])
# ('sure', 'shore', ['I', 'think', 'a'])
# ('has', 'as', ['lead', 'by', '3'])
# ('enough', 'a nougth', ['Enfield', '2', 'and'])
# ('can', 'came', ['and', 'soon', 'made'])
# ('for', 'of', ['dew', 'on', 'it.'])
# ('fattening', 'fating', ['field', 'next', 'to'])
# ('eat', 'eate', ['it', 'was', 'yesterday.'])
# ('bigger', 'biger', ['a', 'lot', 'of'])
# ('fattening', 'fating', ['the', 'river', 'and'])
# ('when', 'whe', ['ducks', 'there', 'were'])
# ('ones', 'wones', ['field', 'to', 'get'])
# ('are', 'and', ['my', 'shoes', '.'])
# ('big', 'bing', ['was', 'quite', 'muddy'])
# ('weighing', 'waying', ['to', 'it', 'nor'])
# ('weighed', 'waid', ['went.', 'the', 'dew'])
# ('ready', 'reddy', ['brussels', 'leaves', 'made'])
# ('killed', 'kild', ['the', 'brook', 'first'])
# ('too', 'to', ['but', 'only', 'one'])
# ('Him', 'Im', ['over', 'the', 'tree'])
# ('Him', 'Im', ['one', 'foot', 'the'])
# ('too', 'to', ['across', 'the', 'new'])
# ('for', 'fro', ['went', 'and', 'our'])
# ('they', 'the', ['my', 'window', 'sill'])
# ('too', 'to', ['my', 'little', 'yellow'])
# ('Troy', 'Toy', ['here', 'talking', 'we'])
# ('thought', 'though', ['here', 'DENNIS', 'Come'])
# ('Royal', 'Royl', ['that', 'would', 'happen'])
# ('fast', 'farst', ['are', 'bright', 'The'])
# ('Royal', 'Royl', ['The', 'are', 'small'])
# ('?', 'Consulatoin', ['in', 'time', 'When'])
# ('Royal', 'Royl', ['the', 'are', 'pips'])
# ('Royal', 'Royl', ['our', 'village', 'go'])
# ('Japanese', 'Japannese', ['with', '.', 'then'])
# ('Honda', 'Hondor', ['fall', 'out', 'in'])
# ('fast', 'farst', ['trees', 'are', 'of'])
# ('getting', 'geting', ['of', 'are', 'cookers.'])
# ('his', 'is', ['I', 'leave', 'school'])
# ('leg', 'lege', ['I', 'leave', 'I'])
# ('another', 'a nouther', ['be', 'a', 'in'])
# ('hurt', 'hearte', ['or', 'I', 'to'])
# ('his', 'is', ['in', 'a', 'shop.'])
# ("don't", 'dont', ['am', '.', 'When'])
# ('think', 'thing', ['have', 'children', 'I'])
# ('saw', 'sow', ['and', 'the', 'has'])
# ('sidecar', 'side car', ['like', 'children', 'and'])
# ('turn', 'turne', ['I', 'twins.', 'and'])
# ('sidecar', 'side care', ['to', 'live', 'in'])
# ('motorbike', 'motor bike', ['like', 'to', 'go'])
# ("don't", 'dont', ['Scotland.', 'On', 'our'])
# ('know', 'no', ['there', 'is', 'a'])
# ('happened', 'hapend', ['made', 'by', 'Mrs'])
# ('hurt', 'heart', ['a', 'real', '.'])
# ('motorbike', 'moter bike', ['on', 'a', 'block'])
# ('spun', 'spund', ['in', 'clay', 'not'])
# ('motorbike', 'moter bike', ['this', 'is', 'very'])
# ('caught', 'caugh', ['and', 'put', 'stamp'])
# ('blew', 'blow', ['this', 'picture', 'there'])
# ('petrol', 'petal', ['out', 'of', 'the'])
# ('soon', 'sone', ['not', 'the', 'arms,'])
# ('There', 'They', ['my', 'day', 'in'])
# ('final', 'fianl', ['the', 'sun,', 'There'])
# ('Royal', 'Royl', ['day', 'People', 'weeping'])
# ('Honda', 'Hondor', ['days', 'hearts', 'are'])
# ('Triumph', 'Triumh', ['so', 'LINDA', 'not'])
# ("they're", 'there', ['to', 'see', 'him'])
# ('Triumph', 'trumh', ['JOHN', 'You', 'what.'])
# ('Honda', 'Hondor', ['her', 'JOHN', 'Yes'])
# ('going', 'go', ['for', 'to', 'be'])
# ("he's", 'his', ['too,', 'still', 'got'])
# ('won', 'one', ['job', 'of', 'her'])
# ('Royal', 'Royl', ['had', 'go', 'home'])
# ('Honda', 'Hondor', ['nothing', 'to', 'think'])
# ('shone', 'shon', ['hello', 'Jean', 'we'])
# ('ploughed', 'ploud', ['about', 'what', 'for'])
# ('done', 'don', ['sorry', 'John.', 'nothing'])
# ('a', 'an', ['mean;', 'one', 'us'])
# ('had', 'hade', ['you', 'JOHN', 'look'])
# ('cleaned', 'cleand', ['am', 'only', 'to'])
# ('for', 'fore', ['I', "won't", 'be'])
# ('potatoes', 'potato', ['to', 'be', 'with'])
# ('pathway', 'parth way', ['you', 'think', 'that'])
# ('ploughed', 'ploud', ['just', 'to', 'me'])
# ('heavy', 'hevey', ['JOHN', 'I', "don't"])
# ('like', 'look', ['at', '6', 'JEAN'])
# ('pearls', 'pirls', ['all', 'right', 'then'])
# ('nearly', 'nealy', ['I', 'am', 'fed'])
# ('touched', 'toch', ['go', 'out', 'with'])
# ('piece', 'pice', ['make', 'up', 'my'])
# ('cleaned', 'cleand', ['that', 'will', 'be'])
# ('break', 'brack', ['had', 'of', 'you'])
# ('hopped', 'hop', ['never', 'come', 'in'])
# ('popped', 'poped', ['again.', 'JILL', 'Well'])
# ('whistled', 'wisheld', ['be', 'out', 'in'])
# ('chirped', 'cherped', ['PARENTS', 'When', 'you'])
# ('tried', 'trid', ['can', 'stay', 'out'])
# ('catch', 'chach', ['Jill', 'ran', 'to'])
# ('bird', 'brid', ['came', 'down,', 'put'])
# ('bird', 'brid', ['Jill', 'went', 'to'])
# ('know', 'no', ['What', 'are', 'you'])
# ("can't", "carn't", ['to', 'see', 'if'])
# ('know', 'no', ['a', 'row', 'with'])
# ("we're", 'were', ['They', 'told', 'me'])
# ('wanted', 'whanted', ['out.', 'JILL', 'my'])
# ("you're", 'your', ['and', 'get', 'married,'])
# ('wanted', 'whated', ['to', 'married.', 'JILL'])
# ('Goodbye', 'Good by', ['do.', 'DAVID', 'Well'])
# ('leaves', 'leavs', ['after.', 'The', 'End.'])
# ('apples', 'apple', ['Melton', '21', 'November'])
# ('autumn', 'Aount', ['thought', 'I', 'had'])
# ('you', 'yow', ['you', 'telling', 'what'])
# ('cores', 'corres', ['with', 'Mr.', 'Holbrook,'])
# ('cores', 'corres', ['a', 'lot', 'of'])
# ('you', 'yow', ['story', 'and', 'letter,'])
# ('throw', 'thorght', ['that', 'it', 'helps'])
# ('cores', 'corres', ['leave', 'school.', 'It'])
# ('burn', 'brun', ['leave', 'school.', 'Love'])
# ('orchard', 'orcher', ['People', 'Rex', 'harrison'])
# ('climb', 'clim', ['television', 'Jean', 'smith'])
# ('them', 'then', ['in', 'Melton.', 'Jean'])
# ('them', 'then', ['Audrey', 'said', 'to'])
# ('earwigs', 'eyewigs', ['Rex', 'is', 'is'])
# ('their', 'there', ['the', 'house', 'of'])
# ('pockets', 'pocket', ['Rex', 'said', 'to'])
# ('apples', 'apple', ['it', 'my', 'house'])
# ('full', 'fall', ['a', 'The', 'gang'])
# ('apples', 'apple', ['and', 'a', 'went'])
# ('them', 'then', ['the', 'gang', 'went'])
# ('hanging', 'haing', ['the', 'shop', 'and'])
# ('them', 'then', ['the', 'gang', 'got'])
# ('them', 'then', ['The', 'Sick', 'Sow.'])
# ('want', 'whant', ['and', 'the', 'old'])
# ('hairdresser', 'hair dreser', ['is', 'so', 'the'])
# ('want', 'whant', ['sow', 'the', 'and'])
# ('want', 'whont', ['the', 'see', 'fat'])
# ('married', 'marryid', ['and', 'went', 'at'])
# ('twenty one', 'twentone', ['the', 'big', 'fat'])
# ('husband', 'husbon', ['and', 'the', '.'])
# ('take', 'tack', ['and', 'he', 'he'])
# ('want', 'whant', ['down', 'and', 'the'])
# ('want', 'whant', ['is', 'and', 'the'])
# ('want', 'whont', ['and', 'the', 'went'])
# ('Butlins', 'butlins', ['sow', 'is', 'and'])
# ('honeymoon', 'hunemoon', ['the', 'and', 'run'])
# ('sculpture', 'sculptor', ['and', 'went', 'and'])
# ('model', 'modal', ['hot', 'and', 'went'])
# ('thing', 'think', ['sow', 'up', 'and'])
# ('model', 'modal', [':', 'Good', 'people'])
# ('standing', 'staning', ['Our', 'old', "Fool's"])
# ('modelled', 'malod', ['it', 'is', 'made'])
# ('model', 'molad', ['unto', 'death', "we'll"])
# ('thing', 'think', ['For', 'as', 'I'])
# ('calmer', 'comer', ['parent', 'to', 'you'])
# ('carefully', 'caresll', ['sport', 'for', 'to'])
# ('people', 'peolpe', ['again', 'and', 'with'])
# ('cruel', 'corller', ['sing', 'Now,', 'old'])
# ('catch', 'cash', ['you', 'know', 'our'])
# ('their', 'there', ['do', 'your', 'body'])
# ('carrying', 'carring', ['And', 'wish', 'the'])
# ('one', 'on', ['he', 'may', 'receive'])
# ('Wings', 'Wing', ['down,', 'and', 'the'])
# ('break', 'brick', ['following', 'song.', 'Good'])
# ("man's", 'mans', ['you', 'see', 'what'])
# ('swans', 'swan', ['have', 'cut', 'down'])
# ('delicate', 'dellitent', ['evening', 'here', 'he'])
# ('things', 'think', ['all', 'in', 'his'])
# ('Poem', 'Pome', ['gore', 'And', 'we'])
# ("daren't", 'darnt', ['the', 'corner', 'to'])
# ("didn't", 'dident', ['sneaking', 'went', 'the'])
# ('quietly', 'quitely', ['sneaking', 'went', 'the'])
# ('Their', 'There', ["O'Malley:", 'Boss', 'George'])
# ('beating', 'beting', ['went', 'the', 'and'])
# ('rapidly', 'raperly', ['and', 'he', 'went'])
# ("I'm", 'I', ['and', 'hit', 'a'])
# ('MARY', 'MARRY', ['THE', 'OLD', 'women'])
# ('here', 'hear', ['she', '29', 'NOVEMBER'])
# ('make', 'mack', ['ft', 'tall', 'he'])
# ("What's", 'What', ['in', 'the', 'hall'])
# ('wrong', 'wong', ['School.', 'The', 'school'])
# ('MARY', 'MARRY', ['a', 'school', 'the'])
# ('taking', 'thaing', ['The', 'House', 'of'])
# ('out', 'owt', ['man', 'is', 'a'])
# ('tonight', 'to night', ['house', 'of', 'house'])
# ('MARY', 'MARRY', ['a', 'man', 'the'])
# ("it's", 'it', ['the', 'police', 'went'])
# ('fault', 'falt', ['house', 'of', 'love'])
# ("it's", 'its', ['got', 'the', 'man'])
# ('fault', 'falt', ['of', 'love', 'the'])
# ('trying', 'traing', ['are', 'a', 'and'])
# ('MARY', 'MARRY', ['of', 'the', 'and'])
# ("you've", 'you', ['at', 'the', 'and'])
# ('choosing', 'ching', ['to', 'tell', 'the'])
# ('better', 'bet', ['are', 'and', 'murdered'])
# ("there's", 'theres', ['the', 'tree', 'Can'])
# ("What's", 'What', ['the', 'tree.', 'The'])
# ('slammed', 'slander', ['London', 'and', 'the'])
# ("can't", 'carnt', ['took', 'him', 'to'])
# ('talk', 'tallk', ['Station', 'and', 'Him'])
# ('decision', 'disson', ['years', 'THE', 'The'])
# ('instance', 'instead', ['went', 'to', 'the'])
# ("there's", 'theres', ['Tony', 'went', 'on'])
# ("There's", 'There', ['I', 'went', 'to'])
# ('no', 'on', ['the', 'Q', 'liner'])
# ('else', 'eles', ['The', 'The', 'Thieves'])
# ('is', 'us', ['see', 'a', 'man'])
# ("it's", 'its', ['car', 'and', 'went'])
# ('trying', 'trining', ['the', 'man', 'went'])
# ('then', 'them', ['station', 'and', 'I'])
# ('rough', 'rought', ['pipe', 'and', 'shook'])
# ('scream', 'scem', ['arrested', 'The', '13'])
# ('scares', 'scards', ['On', 'Monday', 'I'])
# ('warned', 'wornd', ['and', 'went', 'to'])
# ('you', 'yew', ['shop', 'and', 'taking'])
# ('you', 'yow', ['for', 'Jap', 'Case'])
# ('you', 'yow', ['case', 'was', 'arrested'])
# ('want', 'whant', ['case', 'on', 'Friday'])
# ('hurt', 'hert', ['Case', 'was', 'of'])
# ('hurt', 'hert', ['gang', 'Saturday', 'the'])
# ("you're", 'yow', ['to', 'the', 'cafe'])
# ('wrong', 'rong', ['hit', 'the', 'old'])
# ('you', 'yow', ['the', 'cafe', 'and'])
# ('any', 'eney', ['and', 'the', 'down'])
# ('you', 'yow', ['down', 'gang', 'got'])
# ('tonight', 'to night', ['years', 'in', 'jail'])
# ('know', 'no', ['in', 'Jail', 'and'])
# ('you', 'yow', ['husband', 'and', 'told'])
# ("o'clock", 'o, clock', ['said', 'the', 'warder'])
# ("You're", 'Your', ['home.', 'The', '.'])
# ("don't", 'dont', ['day', 'man', 'and'])
# ('know', 'no', ['girl', 'went', 'in'])
# ('goodbye', 'goodby', ['out', 'of', 'the'])
# ('tonight', 'to night', ['old', 'and', 'girl'])
# ('character', 'charickter', ['a', 'walk', 'and'])
# ('Their', 'There', ['old', 'man', 'murder'])
# ('their', 'there', ['went', 'in', 'the'])
# ('you', 'yow', ['at', 'the', 'counter'])
# ('who', 'how', ['and', 'man', 'yes'])
# ('asking', 'arsking', ['the', 'mat', 'died'])
# ('you', 'yow', ['a', 'Walking', 'up'])
# ('else', 'els', ['to', 'see', 'the'])
# ("you'll", 'your', ['I', 'said', 'to'])
# ('yourself', 'your self', ['you', 'I', 'the'])
# ('enough', 'engouh', ['Mr.', 'HoLBook', 'he'])
# ("you'll", 'your', ['I', 'went', 'up'])
# ("that's", 'thats', ['gun', 'and', 'I'])
# ('enough', 'engouh', ['the', 'hill', 'and'])
# ("I'll", 'I', ['you', 'and', 'is'])
# ("that's", 'thats', ['stop', 'the', 'man'])
# ('upstairs', 'up stairs', ['the', 'Irish', 'hit'])
# ("She's", 'She', ['The', 'In', '19'])
# ('whatever', 'what ever', ['10', 'a', 'young'])
# ('happens', 'happends', ['the', 'road', 'coppers'])
# ("boyfriend's", 'boyfrends', ['the', 'young', 'boy'])
# ('opened', 'opend', ['he', 'was', 'John'])
# ('here', 'hear', ['is', 'in', 'An'])
# ('So', 'Show', ['safe', 'and', 'the'])
# ('have', 'has', ['might', 'able', 'to'])
# ("Let's", 'Lets', ['John', 'Smith', 'sandy'])
# ("that's", 'thats', ['a', 'XTV', '212'])
# ('want', 'whont', ['it', 'please', 'ring'])
# ("let's", 'lets', ['his', 'chairs', 'have'])
# ('something', 'somethink', ['Tom', 'Sullivan', 'wears'])
# ('happily', 'happly', ['down', 'the', 'and'])
# ('you', 'yow', ['see', 'a', 'it'])
# ('story', 'stors', ['will', 'sticklebacks', 'out'])
# ('works', 'work', ['in', 'the', 'and'])
# ('factory', 'factoy', ['.', 'A', 'rook'])
# ('works', 'wors', ['and', 'a', 'big'])
# ('?', 'nsor', ['long', 'wings', 'and'])
# ('Watson', 'watston', ['the', 'colour', 'is'])
# ('works', 'wonrs', ['and', 'in', 'the'])
# ('greenhouse', 'gnenhouen', ['blue.', 'The', 'of'])
# ('excited', 'exited', ['James', 'and', 'I'])
# ('went', 'wetn', ['old', 'man', 'house'])
# ('to', 'two', ['Paulkey', 'and', 'John'])
# ('His', 'He', ['has', 'a', 'gun'])
# ('mother', 'mouthr', ['we', 'threaten', 'and'])
# ('said', 'sald', ['went', 'ring', 'the'])
# ('?', 'nis', ['old', 'man', 'went'])
# ('sneaking', 'sneking', ['the', 'gang', 'went'])
# ('teddy boy', 'tedeboy', ['and', 'The', 'boy'])
# ('sneaking', 'sneking', ['run', 'the', 'and'])
# ('to', 'two', ['mat', 'a', 'dog'])
# ('waited', 'wated', ['and', 'cat', 'see'])
# ('teddy boy', 'tedeboy', ['cat', 'ran', 'the'])
# ('teddy boy', 'tedeboy', ['a', 'house', 'and'])
# ('came', 'kom', ['out', 'of', 'the'])
# ('outside', 'out sild', ['mat', 'and', 'dog'])
# ('sneaking', 'sneking', ['the', 'house', 'ran'])
# ('Teddy boy', 'Tedeboy', ['sat', 'on', 'the'])
# ('teddy boy', 'tedeboy', ['boy', 'of', '18'])
# ('One', 'Won', ['on', 'and', 'he'])
# ('farmer', 'frm', ['has', 'not', 'come'])
# ('for', 'four', ['he', 'sun', '.'])
# ('vet', 'vethn', ['house', 'Melton', 'Dear'])
# ("wasn't", "whdn't", ['a', 'better', 'teacher'])
# ('healthy', 'hethy', ['and', 'I', 'your'])
# ('and', 'an', ['is', 'stupid', 'and'])
# ('fit', 'fanit', ['do', 'not', 'like'])
# ('farmer', 'frm', ['two', 'clowns', 'in'])
# ('said', 'sidn', ['ring', 'playing', 'with'])
# ('vet', 'vethn', ['cat', 'some', 'drunk'])
# ('unhealthy', 'on hethy', ['other', 'the', 'crowd'])
# ('vet', 'vethu', ['saw', 'mill', 'with'])
# ('said', 'sidn', ['in', 'the', 'back'])
# ('farmer', 'frmh', ['coming', 'along', 'the'])
# ('come', 'kumh', ['and', 'men', 'tin'])
# ('old', 'lod', ['a', 'hall', 'and'])
# ('said', 'sidn', ['sounds', 'like', 'killed'])
# ('vet', 'vethn', ['YOUNG', 'page', '77'])
# ('farmer', 'frmh', ['6', 'of', 'us'])
# ('to', 'two', ['oldest', 'my', 'the'])
# ('old', 'lod', ['oldest', 'sister', 'is'])
# ('vet', 'vethn', ['of', '3', '.'])
# ('farmer', 'frmh', ['is', '18', 'and'])
# ('old', 'lod', ['for', 'the', 'mobile'])
# ('said', 'sidn', ['a', 'flat', 'at'])
# ('farmer', 'frmh', ['Tonbury', 'my', 'third'])
# ('farm', 'frm', ['at', 'the', 'milk'])
# ('farmer', 'frmh', ['flat', 'with', 'my'])
# ('out', 'ouht', ['sister.', 'I', 'live'])
# ('laid', 'ladh', ['the', 'youngest', 'in'])
# ('farmer', 'frmh', ['get', 'on', 'for'])
# ('too', 'two', ['of', 'things', 'here'])
# ('behind', 'behism', ['dad', 'make', 'a'])
# ('farmer', 'frmh', ['mum.', 'mum', 'Doris'])
# ('his', 'he', ['of', 'tea.', 'Doris'])
# ('?', 'bav', ['you', 'make', 'it.'])
# ('two', 'to', ['I', 'am', 'the'])
# ('lay', 'ladh', ['and', 'have', 'younger'])
# ('vet', 'vetin', ['I', 'have', 'to'])
# ('vet', 'vent', ['are', 'a', 'funny'])
# ('what', 'wat', ['are', 'nice,', 'some'])
# ('wrong', 'ron', ['some', 'will', 'help'])
# ('with', 'wis', ['some', "won't", 'bother,'])
# ('sleep', 'seph', ['my', 'mother.', 'ran'])
# ('vet', 'vethn', ['wall', 'he', 'began'])
# ('to', 'two', ['it', 'when', 'he'])
# ("farmer's", 'frmh', ['the', 'top', 'of'])
# ('vet', 'vethn', ['the', 'other', 'guard'])
# ('farmer', 'framh', ['knife', 'out', 'of'])
# ('vet', 'vethn', ['stole', 'from', 'the'])
# ('said', 'sidn', ['it', 'at', 'the'])
# ('to', 'two', ['it', 'dug', 'into'])
# ('asleep', 'a seph', ['strong', 'he', 'pulled'])
# ('vet', 'vethn', ['he', 'fell', 'off'])
# ('farmer', 'frmh', ['he', 'fell', 'to'])
# ('?', 'sechrus', ['hit', 'the', 'ground'])
# ("pigs'", 'pigs', ['The', 'Jordan', 'family'])
# ('laid', 'ladh', ['happy', 'crowd.', 'The'])
# ('sleep', 'seph', ['a', 'house', 'Just'])
# ('farmer', 'frmh', ['Mother', 'and', 'father'])
# ('vet', 'vethn', ['shouting', 'at', 'each'])
# ('back', 'bakh', ['across', 'the', 'street'])
# ('farmer', 'frmh', ['children', 'would', 'cry'])
# ('went', 'weth', ['was', 'the', 'oldest'])
# ('?', 'ruth', ['than', 'the', 'others.'])
# ('?', 'humit', ['was', '8', 'she'])
# ('woke', 'wok', ['and', 'dad', 'was'])
# ('better', 'beththe', ['He', 'was', 'young'])
# ('End', 'And', ['to', 'understand', 'he'])
# ('you', 'your', ['she', 'held', 'my'])
# ('hands', 'hand', ['me', 'out', 'as'])
# ('sing', 'sings', ['held', 'me', 'down'])
# ('done', 'don', ['took', 'seven', 'to'])
# ('our', 'ous', ['to', 'sit', 'up'])
# ('the', 'ge', ['for', 'children', 'one'])
# ('sun', 'son', ['dad', 'was', 'digging'])
# ('And', 'Ane', ['garden', 'mum', 'had'])
# ('Teddy boy', 'Teddoy', ['farm', 'all', 'my'])
# ('start', 'starte', ['am', 'not', 'but'])
# ('trouble', 'troefle', ['think', 'I', 'know'])
# ('teddy boy', 'teddoy', ['know', 'most', 'about'])
# ('Teddy boy', 'Teddoy', ['little', 'about', 'machinery.'])
# ('round', 'rownd', ['agree', 'with', 'those'])
# ('Teddy boy', 'Teddoy', ['for', 'my', 'living,'])
# ('to', 'two', ['father', 'is', 'a'])
# ('pictures', 'pictyres', ['and', 'I', 'hope'])
# ('manager', 'maneger', ['same', 'Job', 'when'])
# ('stairs', 'stars', ['to', 'take', 'my'])
# ('woman', 'women', ['at', 'easter.', 'that'])
# ('she', 'he', ['I', 'go', 'to'])
# ('?', 'Hurbured', ['farm.', 'I', 'am'])
# ('landed', 'laded', ['is', 'not', 'taking'])
# ('kitchen', 'kitching', ['when', 'I', 'am'])
# ('meadow', 'meadoy', ['average', 'pay', 'a'])
# ('confide', 'cornfield', ['I', 'have', 'farming'])
# ('daffodils', 'daffodill', ['future', '.', '(1)'])
# ('?', 'crowsed', ['2', 'or', '3'])
# ('head', 'hed', ['am', 'have', 'been'])
# ('was', 'wos', ['have', 'worked', 'with'])
# ('teddy boys', 'teddyboys', ['school.', 'So', 'if'])
# ('big-headed', 'Big  haded', ['life,', 'choose', 'FARMING'])
# ('want', 'wat', ['81', 'Dear', 'Rose'])
# ('Teddy boys', 'Taddyboys', ['writing', 'to', 'tell'])
# ('about', 'a Bat', ['I', 'have', 'done'])
# ('knife', 'kniffe', ['Hollbrook.', 'He', 'is'])
# ('shop', 'shap', ['letters', 'or', 'stories.'])
# ('cafe', 'kiffe', ['will', 'me', 'more'])
# ('to', 'two', ['I', 'leave', 'school.'])
# ('to', 'two', ['English', 'but', 'I'])
# ('teddy boys', 'teddyboys', ['Ann', 'Dear', 'Mr'])
# ('knife', 'kiffe', ['hope', 'you', 'will'])
# ('too', 'two', ['come', 'back', 'to'])
# ('dangerous', 'dangers', ['and', 'teach', 'us'])
# ('they', 'the', ['marked', 'the', 'Exams'])
# ('trying', 'try', ['will', 'cheer', 'you'])
# ('car', 'Star', ['sister', 'engaged', 'she'])
# ('questioned', 'question', ['from', 'Melton', 'His'])
# ('End', 'ANd', ['on', 'a', 'farm'])
# ('died', 'ded', ['my', 'works', 'in'])
# ('him', 'hm', ['the', 'college', 'and'])
# ('himself', 'his self', ['the', 'primary.', 'my'])
# ('End', 'ANd', ['at', 'the', 'Handsome'])
# ('story', 'hio', ['meal', 'when', 'he'])
# ('steal', 'still', ['meal', 'when', 'the'])
# ('cops', 'caps', ['then', 'we', 'watch'])
# ('and', 'an', ['work', 'in', 'a'])
# ('cops', 'caps', ['Tonbury', 'where', 'all'])
# ('came', 'kum', ['house', 'I', 'would'])
# ('End', 'And', ['nice', 'to', 'him'])
# ('story', 'shio', ['to', 'me.', 'I'])
# ('sweets', 'swet', ['I', 'would', 'leave'])
# ('was', 'wos', ['children.', 'I', 'would'])
# ('waiting', 'waten', ['a', 'man', 'who'])
# ('guilty', 'guilt', ['I', 'should', 'like'])
# ('End', 'ANd', ['have', 'two', 'big'])
# ('police', 'polic', ['car', 'so', 'that'])
# ('police', 'polic', ['out', 'for', 'ride.'])
# ('came', 'cam', ['like', 'to', 'go'])
# ('police', 'polic', ['round', 'the', 'place.'])
# ('went', 'wen', ['two,', 'four,', 'three'])
# ('see', 'se', ['large', 'birds', 'Sat'])
# ('her', 'She', ['a', 'fence,', 'And'])
# ('went', 'wen', ['I', 'Two', 'teenager'])
# ('it', 'she', ['village', 'when', 'a'])
# ('time', 'tim', ['along', 'and', 'them'])
# ('come', 'coum', ['are', 'mucking', 'about'])
# ('End', 'And', ['road.', 'The', 'boy'])
# ('to', 'two', ['by', 'the', 'shelter'])
# ('man', 'mae', ['it', 'to', 'Joyce'])
# ('to', 'two', ['you', 'want', 'to'])
# ('Police', 'Pollce', ['I', "haven't", 'got'])
# ('did', 'ded', ['boy', 'said', '"shall'])
# ('old', 'lod', ['Joyce', 'still', "hadn't"])
# ('for', 'four', ['I', 'will', 'have'])
# ('murdered', 'murbur', ['I', 'am', 'glad'])
# ('murder', 'murber', ['am', 'going', 'out'])
# ('End', 'And', ['home', 'in', 'the'])
# ('story', 'shio', ['already', 'had', 'a'])
# ('tramps', 'trmp', ['she', 'was', 'waiting'])
# ('tramp', 'trmp', ['Joyce', 'said', 'Roy'])
# ('road', 'rod', ['Roy,', 'Joyce', 'said'])
# ('tramp', 'trmp', ['for', 'a', 'walk.'])
# ('tramp', 'trmp', ['John', 'said', '"if'])
# ('what', 'wat', ['like', 'and', 'so'])
# ('want', 'woth', ['Joyce', 'said', 'to'])
# ('said', 'sald', ['you', 'tonight."', 'for'])
# ('tramp', 'trmp', ['no', 'brothers', 'or'])
# ('eyes', 'eyey', ['you', 'want', 'so'])
# ('he', 'the', ['said', 'if', 'you'])
# ('followed', 'fellowed', ['for', 'you', 'to'])
# ('said', 'sid', ['John.', 'said', 'well'])
# ('home', 'hom', ['had', 'tea', 'and'])
# ('said', 'sid', ['go', 'they', 'said'])
# ('said', 'sid', ['out', 'of', 'the'])
# ('End', 'And', ['picture', 'door', 'they'])
# ('locked', 'lockEd', ['of', 'the', 'film'])
# ('road', 'rad', ['enjoyed', '.', 'They'])
# ('man', 'manh', ['went', 'and', 'had'])
# ('man', 'manh', ['her', 'Goodnight.', 'and'])
# ('man', 'mand', ['told', 'his', 'Mother'])
# ('his', 'he', ['girlfriend', 'So', 'said'])
# ('standard', 'stardnd', ['I', 'will', 'bring'])
# ('ten', 'tan', ['tomorrow.', 'So', 'John'])
# ('Yard', 'Ysid', ['to', 'meet', 'your'])
# ('End', 'And', ['John', 'Joyce', 'to'])
# ("Tom's", 'Toms', ['Mother', 'John', 'Mother'])
# ('stinks', 'sticks', ['then', 'his', 'father'])
# ('mother', 'morther', ['and', 'to', 'get'])
# ('trashy', 'tashie', ['engagement', 'is', 'Dec'])
# ('field', 'fed', ['the', 'at', 'his'])
# ('fish', 'fsh', ['that', 'Joyce', 'had'])
# ('air', 'hare', ['first', 'and', 'then'])
# ('water-rat', 'waterrat', ['up', 'to', 'John'])
# ('field', 'fed', ['all', 'said', 'Congratulations'])
# ('to', 'two', ['both', 'said', 'Thank'])
# ('school', 'shool', ['to', 'have', 'two'])
# ('come', 'com', ['star', 'My', 'best'])
# ('sea', 'see', ['like', 'Cliff', 'to'])
# ('sea', 'see', ['song', 'is', 'do'])
# ('sea', 'see', ['have', 'not', 'heard'])
# ('sea', 'see', ['are', 'the', 'Beverly'])
# ('feet', 'fet', ['the', 'and', 'Everly'])
# ('to', 'two', ['As', 'I', 'looked'])
# ('Porky', 'Paulkey', ['think', 'the', 'people'])
# ('to', 'two', ['The', 'woman', 'put'])
# ('he', 'the', ['was', 'dark', 'in'])
# ('ambulance', 'amblance', ['to', 'me', 'as'])
# ('to', 'tow', ['licking', 'up', 'the'])
# ('to', 'two', ['his', 'cage', 'wondering'])
# ('dying', 'dieing', ['shoes.', 'socks', 'come'])
# ('home', 'homse', ['legs', 'like', 'long'])
# ('to', 'two', ['fire.', 'When', 'a'])
# ('door', 'boor', ['in', 'her', 'Pram'])
# ('to', 'qu', ['order', 'her', 'weekly'])
# ('wall', 'molh', ['course', 'she', 'left'])
# ('roof', 'rhfn', ['Her', 'baby', 'was'])
# ('chimney', 'cimbenr', ['the', 'little', 'baby'])
# ('fire', 'fiar', ['could', 'not', 'talk'])
# ('jumped', 'jumth', ['little', 'words.', 'Mum'])
# ('his', 'he', ['"Now', 'what', 'are'])
# ('seat', 'sat', ['crying', 'for', 'My'])
# ('over', 'ove', ['"Man,', 'Man,",', 'he'])
# ('out', 'ou', ['the', 'road,', 'at'])
# ('to', 'two', ['she', 'could', 'not'])
# ('wall', 'wah', ['black', 'baby', 'in'])
# ('to', 'two', ['blue', 'pram', 'And'])
# ('the', 'he', ['woman', 'came', 'over'])
# ('went', 'wens', ['know', 'that', 'old'])
# ('army', 'hrmehr', ['gone', 'down', 'the'])
# ("didn't", 'denat', ['he', 'tried', 'to'])
# ('like', 'lichr', ['your', 'little', 'baby'])
# ('army', 'hrmehn', ['pram.', 'So', 'she'])
# ('leave', 'lefnr', ['much', 'for', 'telling'])
# ("didn't", 'dednt', ['"goodbye', 'So', 'the'])
# ('come', 'comr', ['with', 'her', 'baby.'])
# ('douche', 'back', ['time', 'she', 'went'])
# ('by', 'bihr', ['some', 'bread.', 'The'])
# ('captain', 'cpn', ['with', 'the', 'baby'])
# ('said', 'sedn', ['outside', 'the', 'fishmonger,'])
# ('back', 'doc', ['Lady', 'went', 'in,'])
# ('yet', 'yeth', ['while', 'she', 'was'])
# ('down', 'dus', ['.', 'So', 'he'])
# ('?', 'unz', ['the', 'white', 'one'])
# ('road', 'rod', ['had', 'the', 'black'])
# ('London', 'Londod', ['of', 'course', 'he'])
# ('think', 'thank', ['a', 'saw', 'the'])
# ('think', 'tink', ['went', 'home', 'while'])
# ('idea', 'ida', ['her', 'jobs', 'she'])
# ('yours', 'yourns', ['to', 'herself', '"the'])
# ('circus', 'sercus', ['see', 'if', 'he'])
# ('around', 'a round', ['She', 'opened', 'the'])
# ('pointing', 'pooting', ['shouted.', 'after', 'she'])
# ('meadow', 'medow', ['here', 'in', 'a'])
# ('road', 'raod', ['had', 'a', 'knock'])
# ('siren', 'satren', ['she', 'said', '"Come'])
# ('hammering', 'hemmsering', ['policemen.', 'The', 'police'])
# ('many', 'meny', ['"What', 'can', 'we'])
# ('metals', 'metet', ['for', 'you', 'Miss.'])
# ('or', 'ot', ['she', 'said', '"This'])
# ('dance', 'dane', ['white', 'one', 'so'])
# ('young', 'yung', ['when', 'did', 'you'])
# ('peep', 'peope', ['find', 'out', 'she'])
# ('dancing', 'pncing', ['just', 'a', 'minute'])
# ('?', 'anetes', ['you.', 'One', 'of'])
# ('got', 'gnt', ['police', 'said', '"did'])
# ('There', 'They', ['while', 'I', 'went'])
# ("dad's", 'dads', ['crying)', 'The', 'other'])
# ("mum's", 'mums', ['the', 'whole', 'story"'])
# ('married', 'marrede', ['they', 'wanted', 'a'])
# ('months', 'month', ['So', 'she', 'put'])
# ('company', 'coperney', ['still', 'they', "couldn't"])
# ('person', 'peason', ['to', 'her', 'house'])
# ('picked', 'picted', ['the', 'baby', 'and'])
# ('says', 'sais', ['#5', 'and', 'shared'])
# ('says', 'seis', ['after', 'and', 'took'])
# ('says', 'sais', ['a', 'time', 'were'])
# ('says', 'sais', ['parents', "wouldn't", 'let'])
# ('Sylvia', 'sylver', ['not', 'she', 'were'])
# ('Sylvia', 'Sylver', ['had', 'a', 'boyfriend'])
# ('says', 'sais', ['so', 'did', 'he'])
# ('no one', 'now one', ['The', 'big', 'day'])
# ("that's", 'thats', ['were', 'over', 'She'])
# ('Macwilliams', 'macwillaims', ['the', 'door', 'with'])
# ('pulled', 'pull', ['into', 'the', 'room'])
# ('which', 'witch', ['living', 'by', '.'])
# ('kitchen', 'kichen', ['serious', 'talk', 'thinking'])
# ('threw', 'frow', ['a', 'family', 'of'])
# ('Macwilliams', 'macwillaims', ['So', 'they', 'went'])
# ('forward', 'forword', ['news', '.', 'he'])
# ('almighty', 'almity', ['and', 'when', 'they'])
# ('died', 'diad', ['their', 'own', '.'])
# ('lived', 'lifd', ['when', 'you', 'pick'])
# ('council', 'counsel', ['red', 'and', 'before'])
# ('outside', 'out side', ['makes', 'your', 'mouth'])
# ('London', 'Londen', ['even', 'makes', 'your'])
# ('went', 'whenet', ['you', 'hear', 'the'])
# ('fighting', 'figthing', ['getting', 'some', "gascoyne's"])
# ('grown', 'groon', ['if', 'you', 'do'])
# ('Joan', 'Jone', ['gascoyne', 'scarlet', 'apples.'])
# ('too', 'to', ['and', 'plums,', 'pears.'])
# ('nevertheless', 'never the less', ['people', 'or', 'you'])
# ('died', 'diad', ['they', 'make', 'too'])
# ('there', 'they', ['climb', 'over', 'the'])
# ('of', 'off', ['the', 'man', 'will'])
# ('slowly', 'slolly', ['might', 'hit', 'you'])
# ('stopped', 'stoped', ['they', 'will', 'hit'])
# ('until', 'untill', ['orchard', 'again', 'But'])
# ('had', 'have', ['an', 'orchard', 'where'])
# ('he', 'his', ['who', 'owns', 'the'])
# ('carried', 'carred', ['take', 'the', 'bikes'])
# ('be', 'me', ['have', 'to', 'go'])
# ('destroyed', 'distrod', ['ask', 'for', 'it'])
# ('baths', 'bath', ['the', 'owner', 'of'])
# ('clean', 'clearn', ['you', 'were', 'in'])
# ("I'm", 'Im', ['I', 'never', 'take'])
# ('allowed', 'alloud', ['or', 'a', 'red'])
# ('programmes', 'programes', ['easy', 'because', 'red'])
# ('suitable', 'surtebull', ['very', 'easy.', 'But'])
# ('there', 'they', ['sly', 'old', 'beast'])
# ('unfit', 'unfitt', ['and', 'waiting', 'To'])
# ('others', 'other', ['gone', 'to', 'collect'])
# ('stabbed', 'stabed', ['leap.', 'Chickens', 'cackle'])
# ('of', 'off', ['are', 'numb', 'But'])
# ('boasting', 'bosting', ['A', 'tree', 'is'])
# ('paid', 'payed', ['One', 'day', 'at'])
# ('employment', 'imployment', ['was', 'wrecked', 'by'])
# ('sitting', 'siting', ['case', 'of', 'life'])
# ('stuffy', 'stufy', ['ship', 'was', 'sinking'])
# ('apprenticeship', 'apprentiship', ['get', 'some', 'diving'])
# ('classes', 'classis', ['to', 'the', 'store'])
# ('once', 'ones', ['were', 'dead', 'on'])
# ('useful', 'usfull', ['on', 'the', 'island.'])
# ('While', 'Will', ['the', 'island', 'went'])
# ('getting', 'get', ['as', 'he', 'went'])
# ('shillings', 'shilling', ['the', 'surface', 'of'])
# ('Apprenticeship', 'Apprentiship', ['the', 'diving', 'suits.'])
# ('of', 'off', ['surface', 'and', 'that'])
# ('chosen', 'choosen', ['to', 'the', 'people'])
# ('career', 'carrer', ['sent', 'men', 'to'])
# ('different', 'diffrent', ['some', 'food.', 'enough'])
# ('anything', 'enthing', ['for', 'the', 'people'])
# ('working', 'work', ['had', 'a', 'little'])
# ('given', 'give', ['had', 'one', 'tin'])
# ('leave', 'life', ['food', 'to', 'eat'])
# ('wants', 'want', ['they', 'started', 'looking'])
# ('always', 'all ways', ['get', 'coconuts', 'got'])
# ('do', 'done', ['15.', 'They', 'kept'])
# ('sometimes', 'some thime', ['sea', 'if', 'they'])
# ('yours', 'you', ['of', 'the', 'inside.'])
# ('There', 'They', ['holes', 'dug', 'in'])
# ('and', 'a', ['night', 'they', 'slept'])
# ('brothers', 'brother', ['delighted.', 'As', 'soon'])
# ('sisters', 'sister', ['to', 'be', 'on'])
# ('comes', 'come', ['a', 'ship', 'again'])
# ('?', 'Half-hose', ['June', 'and', 'we'])
# ('likes', 'like', ['WALTER', 'PERKINS', 'page'])
# ('wavy', 'wavey', ['the', 'cat.', 'swing'])
# ('boyfriend', 'boyfrend', ['her', 'little', 'boy'])
# ('hates', 'hate', ['we', 'went', 'on'])
# ('prayer-book', 'prayerbook', ['standing', 'at', 'the'])
# ('colour', 'colur', ['see', 'that', 'he'])
# ('clothes', 'colhes', ['and', 'to', 'take'])
# ('dense', 'dence', ['men', 'came', 'rushing'])
# ('CHARACTERS', 'CHARTORS', ['for', 'the', 'gun'])
# ('asks', 'ask', ['the', 'bunk', 'the'])
# ("boy's", 'boys', ['body', 'to', ','])
# ("haven't", "haven's", ['.', 'Dear', 'Sir,'])
# ('prettiest', 'prettest', ['it.', 'So', 'it'])
# ('answered', 'anwerd', ['is', 'all', 'right.'])
# ('asked', 'ask', ['Italian', 'suit', 'on'])
# ('her', 'he', ['and', 'my', 'Mum'])
# ('here', 'hear', ['farm', 'and', 'Six'])
# ('comes', 'come', ['cows;', 'One', 'day'])
# ("Whoever's", 'Whos evers', ['did', 'not', 'was'])
# ("Jean's", 'jeans', ['her', 'mouth', 'was'])
# ('Cheerio', 'Cheere ho', ['the', 'market', 'had'])
# ("Joyce's", 'Joyce', ['was', 'open', 'I'])
# ('parents', 'prarents', ['to', 'the', 'market'])
# ("whoever's", 'who evers', ['some', 'pigs,', 'and'])
# ('parents', 'prerents', ['it', 'back', 'by'])
# ('go', 'do', ['some', 'more', 'bullocks,'])
# ('pictures', 'picture', ['got', 'and', 'got'])
# ('walked', 'walk', ['wife', 'I', 'have'])
# ("Jean's", 'Jeans', ['the', 'if', 'I'])
# ('he', 'the', ['land', 'to', 'a'])
# ('Roy', 'Roys', ['on', 'so', 'I'])
# ("o'clock", 'O clock', ['We', 'England', 'to'])
# ('their', 'they', ['the', 'world.', 'The'])
# ('cheerio', 'cheeroh', ['a', 'Slaughterhouse', 'in'])
# ("don't", 'want', ['I', 'am', 'the'])
# ('the', 'they', ['the', 'men.', 'On'])
# ('their', 'there', ['finished', 'the', 'Bullocks'])
# ('got', 'go', ['I', 'go', 'back'])
# ("wasn't", 'wasnt', ['the', 'table.', 'I'])
# ('myself', 'my shelf', ['the', 'pluck', 'up'])
# ('stopped', 'stop', ['that', 'goes', 'on'])
# ("Joyce's", 'Joyce', ['until', 'they', 'let'])
# ('Motorbike', 'Motor-bikes', ['the', 'guts.', 'all'])
# ('they', 'there', ['The', 'end.', '9.'])
# ('night', 'tonight', ['the', 'name', 'was'])
# ('went', 'sent', ['told', 'him', 'that'])
# ('over', 'ove', ['was', 'a', '.'])
# ("John's", 'John', ['were', 'going', 'the'])
# ('introduced', 'introducted', ['told', 'her', 'he'])
# ('decided', 'dicide', ['at', '70', 'pm.'])
# ('Married', 'Marrid', ['Mary', 'gave', 'a'])
# ('special', 'spicil', ['are', 'have', 'a'])
# ('the', 'they', ['was', '6', 'months'])
# ('Their', 'There', ['One', 'night', 'in'])
# ('engagement', 'enagement', ['I', 'had', 'a'])
# ('engaged', 'enaged', ['hear', 'if', 'the'])
# ('presents', 'present', ['the', 'door', 'was'])
# ('too', 'two', ['bed', 'But', 'my'])
# ('the', 'they', ['mixed', 'up', 'English'])
# ('walked', 'walk', ['corn.', 'The', 'cat'])
# ('their', 'they', ['and', 'a', 'little'])
# ('their', 'they', ['cat', 'it', 'and'])
# ('decided', 'decider', ['for', 'a', 'year'])
# ('children', 'chidren', ['of', 'oranges', 'in'])
# ("Adam's", 'Adam', ['old', 'he', 'had'])
# ('what', 'want', ['for', ',', 'stealing'])
# ("don't", 'don', ['will', 'you', 'do'])
# ('beverley', 'beverly', ['Sunday', 'night', 'on'])
# ('sisters', 'sister', ['market', 'hill,', 'it'])
# ('know', 'no', ['10', 'coloured', 'red'])
# ('beverley', 'beverly', ['and', 'covered', 'up.'])
# ('beverley', 'beverly', ['It', 'must', 'in'])
# ('drunk', 'druck', ['and', 'up', 'the'])
# ('things', 'thinks', ['he', 'had', 'one'])
# ('was', 'we', ['get', 'to', 'a'])
# ('painted', 'panted', ['he', 'comes', 'to'])
# ('outside', 'out side', ['Bob', 'did', 'not'])
# ('happening', 'happing', ['the', 'police', 'so'])
# ('fashioned', 'fashion', ['near', 'Clare', 'he'])
# ('Their', 'They', ['police', 'car', 'coming'])
# ('their', 'they', ['window', '"You', 'have'])
# ("grandpa's", 'grandpas', ['with', 'a', 'of'])
# ('outside', 'out side', ['and', 'got', 'the'])
# ('His', "He's", ['in', 'a', 'corner.'])
# ('meant', "mean't", ['"good', 'morning', 'Bob"'])
# ('and', 'a', ['of', '#1', 'out'])
# ('where', 'were', ['the', 'money', 'to'])
# ('your', 'you', ['just', 'going', 'to'])
# ('mother', 'mothers', ['it.', 'Bob', 'bent'])
# ('has', 'as', ['and', 'him', 'out.'])
# ('its', "it's", ['found', 'out', 'that'])
# ('walked', 'walk', ['the', 'of', 'the'])
# ('babies', 'babys', ['the', 'police', 'car'])
# ('and', 'a', ['police', 'went', 'in'])
# ('asleep', 'a sleep', ['the', 'and', 'his'])
# ('baby', 'babys', ['but', 'he', 'got'])
# ('door', 'down', ['getting', 'dark', 'and'])
# ('saw', 'sow', ['cold.', 'It', 'must'])
# ('phoned', 'phone', ['a', 'farmhouse', 'it'])
# ('minutes', 'minetes', ['He', 'could', 'see'])
# ('outside', 'out side', ['he', 'did', 'not'])
# ('and', 'aud', ['Tom', 'the', 'two'])
# ('them', 'then', ['a', 'hide', 'made'])
# ('after a while', 'afterawhile', ['out', 'of', 'the'])
# ('woman', 'women', ['or', '4', 'and'])
# ('policemen', 'polce men', ['his', 'and', 'the'])
# ('woman', 'women', ['went', 'back', 'for'])
# ('grabbed', 'grab', ['more.', 'He', 'did'])
# ('pounds', 'ponds', ['on', 'the', 'loft.'])
# ('pounds', 'ponud', ['right', 'shoot"', 'the'])
# ('always', 'all ways', ['here', '"', 'Tom'])
# ('wherever', 'were ever', ['to', 'Tom', 'well'])
# ('there', 'the', ['again', 'I', 'will'])
# ('until', 'untill', ['field', 'next', 'day'])
# ('his', "he's", ['starting', 'from', 'the'])
# ("girl's", 'girls', ['Leon,', 'Dilys,', 'Derek'])
# ('altar', 'alter', ['DIED', 'SLOWLY', 'day'])
# ('boyfriend', 'boy friend', ['his', 'wife', 'was'])
# ('tied', 'tired', ['for', 'a', 'ride'])
# ('themselves', 'they self', ['was', 'a', 'car'])
# ('their', 'they', ['was', 'in', 'flames'])
# ('happened', 'happen', ['the', 'door', 'and'])
# ('pregnant', 'pregant', ['a', 'field.', 'Paul'])
# ('their', 'they', ['he', 'could', 'to'])
# ('families', 'familys', ['nail', 'was', 'near'])
# ('careful', 'carefull', ['IN', 'minutes', 'she'])
# ('apples', 'apple', ['14', 'shot', 'his'])
# ('too', 'to', ['not', 'give', 'him'])
# ('especially', 'a specally', ['gun', 'at', 'him'])
# ('careful', 'carful', ['not', 'give', 'me'])
# ('wherever', 'where ever', ['him', 'in', 'the'])
# ('someone', 'some one', ['house', 'she', 'father'])
# ('barbed', 'barb', ['DIMMOX', 'THE', 'OLD'])
# ('probably', 'probally', ['the', 'road', 'one'])
# ('they', 'the', ['then', 'they', 'ran'])
# ('say', 'said', ['from', 'his', 'nose.'])
# ('recognized', 'reconnised', ['done', 'that', 'peter'])
# ('another', 'a nother', ['they', 'went', 'to'])
# ('Stranded', 'Stranden', ['was', 'late', 'for'])
# ('midsummer', "midsummer's", ['dead.', 'left', 'leg'])
# ('coral', 'corral', ['for', 'the', 'police'])
# ('outfits', 'out fits', ['was', 'unable', 'to'])
# ('volunteered', 'volonteered', ['she', 'had', 'the'])
# ('There', 'Their', ['and', 'jane', 'got'])
# ('bodies', 'bodys', ['they', 'were', 'going'])
# ('shipwreck', 'ship wreck', ['weeks', 'had', 'gone'])
# ('There', 'Their', ['taking', 'about', 'and'])
# ('opened', 'open', ['a', 'holiday', 'to'])
# ('two', 'to', ['sisters,', 'one', 'Janet'])
# ('then', 'the', ['get', 'blamed', 'for'])
# ('Lucky', 'Luckily', ['else', 'I', 'get'])
# ('tinned', 'tin', ['a', 'bag', 'nearly'])
# ('lifeboat', 'life boat', ['the', 'old', 'man'])
# ('used', "use't", ['meet', 'all', 'kinds'])
# ('usually', 'usally', ['a', 'farm', 'attached'])
# ('shortened', 'shortend', ['a', 'few', 'down'])
# ('down', 'done', ['road', 'in', 'a'])
# ('killed', 'kill', ['cow', 'and', 'one'])
# ('ground', 'gound', ['I', 'started', 'the'])
# ('laid', 'laide', ['and', 'went', 'out'])
# ('as', 'ass', ['This', 'is', 'the'])
# ('evening', 'evining', ['fly', 'out', 'of'])
# ("father's", "farther's", ['with', 'water', 'it'])
# ('reading', 'reding', ['as', 'big', 'round'])
# ('coat', 'cote', ['up', 'the', 'farm'])
# ('hook', 'hock', ['me', 'that', 'he'])
# ('dark', 'dork', ['I', 'said', 'let'])
# ('GARDEN', 'GARDON', [',', 'so', 'we'])
# ('Cheetah', 'Cheter', ['and', 'she', 'was'])
# ('cheetah', 'cheter', ['the', 'right,', 'front'])
# ('prowls', 'prouls', ['I', 'said', 'to'])
# ('undergrowth', 'undergroth', ['feed', 'very', 'well,'])
# ('jungle', 'jungel', ['on', 'her', 'front'])
# ('clatter', 'clater', ['she', 'will', 'not'])
# ('their', 'there', [',', 'well', 'let'])
# ('jungle', 'jungel', ['So', 'Bill', 'showed'])
# ('Monkeys', 'Munces', ['said', 'you', 'give'])
# ('little', 'litel', ['you', 'are', 'that'])
# ('cheetah', 'cheter', ['tonight', 'and', 'then'])
# ('roars', 'rorse', ['if', 'she', 'will'])
# ('falls', 'forls', ['I', 'could', 'give'])
# ('cheetah', 'cheter', ['you', 'wish', 'Look'])
# ('caught', 'cort', ['see', 'she', 'will'])
# ('prey', 'pray', ['now', 'yes', 'John,'])
# ('Death', 'Dearth', ['She', 'is', 'in'])
# ('when', 'wen', ['have', 'them', 'on'])
# ('having', 'haveing', ['Well', 'I', 'one'])
# ('breakfast', 'brecfast', ['you', 'to', 'do.'])
# ('came', 'come', ['John,', 'you', 'to'])
# ('bitten', 'biten', ['The', 'Old', 'Bull'])
# ("boy's", 'boys', ['round', 'old', 'man'])
# ('Hong Kong', 'Honk Kong', ['the', 'gate', 'the'])
# ('took', 'tuck', ['man', 'Jones,', 'said'])
# ('houseboat', 'house boat', ['minutes', 'after,', 'I'])
# ('thought', 'thort', ['the', 'cart.', 'They'])
# ('queer', 'quere', ['back', 'in', 'the'])
# ('houseboat', 'house boat', ['me', 'if', 'I'])
# ('were', 'where', ['daisy', 'the', 'old'])
# ('four', 'fore', ['up', 'to', 'go'])
# ('sitting', 'siting', ['bull,', 'because', 'he'])
# ('chair', 'chere', ['ought', 'to', 'have'])
# ('where', 'were', ['and', 'we', 'let'])
# ('entered', 'enterd', ['with', 'about', 'half'])
# ("that's", 'thats', ['she', 'had', 'a'])
# ('what', 'wat', ['it', 'was', 'a'])
# ('bullet', 'bolot', ['made', '#15.10s.6d.', 'Then'])
# ('equipment', 'aquitment', ['and', 'fat', 'for'])
# ('write', 'rite', ['tonbury', 'market', 'and'])
# ('piece', 'pese', ['one', 'and', 'a'])
# ('what', 'wot', ['A', 'brown', 'study'])
# ('need', 'nede', ['in', 'a', 'sort'])
# ('of', 'on', ['Fighting', 'with', 'your'])
# ('once', 'wons', ['ground', 'are', 'feathers.'])
# ('when', 'wen', ['It', 'is', 'ten'])
# ('bullet', 'bulete', ['accident', 'he', 'was'])
# ('wait', 'wat', ['Bob', 'fell', 'into'])
# ('what', 'wot', ['home', 'from', 'church'])
# ('happened', 'hapends', ['Sunday', 'night', 'we'])
# ('Outside', 'Out side', ['our', 'on.', 'The'])
# ('missed', 'mist', ['the', 'road', 'he'])
# ('missed', 'mist', ['a', 'sound', 'and'])
# ('too', 'to', ['stairs', 'and', 'opened'])
# ('man', 'may', ['out', 'into', 'the'])
# ('stopped', 'stoped', ['lorry', 'it', 'killed'])
# ('bullet', 'bulet', ['he', 'was', 'only'])
# ('took', 'tuck', ['I', 'am', 'just'])
# ('prison', 'prisin', ['his', 'grave', 'are'])
# ('bullet', 'bulet', ['was', 'a', 'bit'])
# ('suddenly', 'suddenel', ['Rex', 'said', 'Audrey'])
# ('It', 'I', ['is', 'rather', 'dark'])
# ('had', 'has', ['be', 'dark', 'you'])
# ('cane', 'cain', ['it', 'will', 'be'])
# ('teachers', 'teacher', ['audrey', 'said', 'kissing'])
# ('cane', 'cain', ['it.', 'audrey', 'said'])
# ('Bicycle', 'Bicyle', ['will', 'you', 'kiss'])
# ('do not', 'donot', ['well', 'then.', 'She'])
# ('wrong', 'rong', ['how', 'did', 'that'])
# ('father', 'farther', ['glad', 'to', 'meet'])
# ('Father', 'Farther', ['down', 'the', 'said'])
# ('sometimes', 'some time', ['he', 'gave', 'it'])
# ('pair', 'per', ['will', 'be', 'enough'])
# ('fly', 'fie', ['On', 'day', 'in'])
# ('and', 'a', ['autunm', '</ERR>', 'pick'])
# ('feet', 'fee', ['when', 'you', 'pick'])
# ('cannot', 'can not', ['spur', 'with', 'the'])
# ('flies', 'fies', ['it', 'but', 'that'])
# ('sexton', 'sixty one', ['lovely', 'it', 'has'])
# ('sows', 'sow', ['you', 'feel', 'so'])
# ('know', 'no', ['see', 'light', 'On'])
# ('what', 'wot', ['fair', 'They', 'have'])
# ('?', 'solued', ['lot', 'of', 'light'])
# ('sore', 'saw', ['candles', 'Because', 'I'])
# ('foot-and-mouth', 'footandmouth', ['the', 'way', 'Poem'])
# ('killed', 'kid', ['true', 'I', 'lay'])
# ('area', 'airaear', ['all', 'night', 'Until'])
# ('stopped', 'stoped', ['Oh', 'why', 'do'])
# ('After', 'Artair', ['dreams', 'And', 'think'])
# ('there', 'their', ['Oh', 'why.', 'I'])
# ('been', 'bine', ['go', 'to', 'bed'])
# ('another', 'aner', ["don't", 'feel', 'very'])
# ('outbreak', 'outdrak', ["don't", 'stay', 'up'])
# ('foot-and-mouth', 'footanmouth', ['will', 'you', 'I'])
# ('were', 'wher', ['I', 'come', 'now'])
# ('killed', 'kid', ['said', 'that.', 'Sorry'])
# ('selling', 'seling', ['way', 'you', 'said'])
# ('sold', 'soled', ['go', 'out', 'you'])
# ('them', 'the', ['need', 'your', 'coats'])
# ('for the', 'fort', ['gloves', 'it', 'is'])
# ("Castle's", 'castels', ['5', 'we', 'to'])
# ('me', 'we', ['month', 'ago', 'died'])
# ('enough', 'a nuff', ['a', 'little', 'girl'])
# ('build', 'buld', ['of', 'us', 'if'])
# ('slaughterhouse', 'slaughthouse', ['lived', 'she', 'would'])
# ('asked', 'arsed', ['blind', 'deaf', 'and'])
# ('council', 'cousall', ['my', 'father', 'I'])
# ('could', 'cod', ['crying', 'it', 'on'])
# ('build', 'billed', ['my', 'little', 'brother'])
# ('slaughterhouse', 'slaughthouse', ['he', 'on', 'hitting'])
# ('council', 'counsall', ['when', 'he', 'get'])
# ('replied', 'replid', ['own', 'way', 'but'])
# ('could', 'cod', ['and', 'his', 'name'])
# ('wrote', 'roat', ['day', 'I', 'went'])
# ('biggest', 'bigest', ['things', 'but', 'I'])
# ('building', 'billding', ['not', 'like', 'some'])
# ('firms', 'ferman', ['the', 'girls', 'they'])
# ('asked', 'arsed', ['some', 'of', 'them'])
# ('billed', 'build', ['there', 'them', 'play'])
# ('slaughterhouse', 'slaughthouse', ['to', 'in', 'then'])
# ('replied', 'replid', ['bit', 'better', 'then'])
# ('build', 'billd', ['me', 'and', 'in'])
# ('Slaughterhouse', 'Slaughthouse', ['to', 'in.', 'When'])
# ('enough', 'nuff', ['toys', 'toys', 'toys'])
# ('retire', 'retier', ['is', 'a', 'big'])
# ('slaughterhouse', 'slaughthouse', ['in', 'little', 'dots'])
# ('animals', 'animl', ['in', 'carefully', 'otherwise'])
# ('left', 'lift', ['you', 'that', 'very'])
# ('France', 'Fance', ['to', 'get', 'the'])
# ('main', 'mane', ['to', 'make', 'your'])
# ('parts', 'pars', ['.', 'One', 'day'])
# ('there', 'their', ['in', 'a', 'few'])
# ('be', 'by', ['but', 'I', 'set'])
# ('inside', 'in side', ['of', 'mud', 'and'])
# ('hang', 'hung', ['to', 'find', 'anther'])
# ('cleaned', 'clean', ['for', 'them', 'I'])
# ('do', 'go', ['of', 'old', 'age'])
# ("boy's", 'boy', ['I', 'have', 'some'])
# ('James', 'Jame', ['a', 'few', '.'])
# ('James', 'Jame', ['to', 'find', 'a'])
# ('friends', 'frens', ['cool', 'it', 'about'])
# ('prostitute', 'prostut', ['then', 'they', 'grow'])
# ('next', 'nest', ['they', 'get', 'bigger'])
# ('James', 'Jame', ['but', 'last', 'year'])
# ('telephoned', 'telphoned', ['eggs', 'around', 'I'])
# ('seeing', 'see', ['went', 'down', 'the'])
# ('again', 'agan', ['the', 'bridge', 'there'])
# ('said', 'sed', ['50', 'eggs.', 'I'])
# ('tonight', 'to night', ['and', 'them', 'up'])
# ('James', 'Jame', ['weed', 'they', 'must'])
# ('common', 'comon', ['use', 'a', 'big'])
# ('James', 'Jame', ['my', 'frog', 'in'])
# ('Durex', 'Durxer', ['they', 'get', 'to'])
# ('sexual', 'sexul', ['of', 'my', 'garden'])
# ('intercourse', 'intercors', ['is', 'a', 'stream'])
# ('said', 'sed', ['the', 'back', 'and'])
# ('goodbye', 'good-by', ['in', 'the', 'water'])
# ('later', 'lated', ['swim', 'away.', 'is'])
# ('discovered', 'dicuverd', ['the', 'away', 'when'])
# ('she', 'the', ['tail', 'then', 'you'])
# ('pregnant', 'pregnet', ['live', 'and', 'just'])
# ('later', 'latter', ['you', 'must', 'keep'])
# ('Smoking', 'Smocking', ['a', 'bit', 'of'])
# ('house', 'houes', ['and', 'that', 'will'])
# ('while', 'wil', ['a', 'cool', 'afternoon'])
# ('listening', 'lsning', ['a', 'sort', 'of'])
# ('stairs', 'sairs', ['me', 'a', 'sort'])
# ('creak', 'creek', ['I', 'still', 'keep'])
# ('caught', 'cort', ['came', 'to', 'the'])
# ('indiscreet', 'indiscrest', ['then', 'I', 'on'])
# ('till', 'utill', ['of', 'a', 'sort'])
# ('opened', 'open', ['stood', 'looking', 'out'])
# ('flash', 'flass', ['started', 'to', 'get'])
# ("mum's", 'mums', ['I', 'could', 'her'])
# ('bloody', 'bludy', ['swing', 'in', 'the'])
# ('Nose', 'Nos', ['felt', 'a', 'bit'])
# ('simple', 'simpl', ['people', 'Once', 'a'])
# ("author's", 'others', ['milk', 'man', 'came'])
# ('tongue', 'tung', ['did', 'not', 'say'])
# ...
# ('noise', 'nose', ['is', 'nonsense,', 'he'])
# ('Someone', 'Some one', ['enough', 'teacher,', 'for'])
# ('tape', 'tipped', ['learn', 'from.', 'We'])
# ('what', "wha't", ['writing', 'them.', 'Mr'])
# ('who', 'how', ['we', 'are', 'told'])
# ('taken', 'tackon', ['will', 'have', 'no'])
# ('stolen', 'stowlen', ['stories,', 'I', 'think'])
# ('found', 'fond', ['much', 'more', 'important'])
# ('ditch', 'dich', ['Judith', 'When', 'we'])
# ('mine', 'my', ['a', 'story,', 'and'])
# ('there', 'their', ['we', 'write', '4'])
# ('worry', 'worye', ['of', 'the', 'idea'])
# ('policeman', 'police man', ['soft', 'on', 'us'])
# ('asked', 'ask', ['Stall', 'I', 'think'])
# ('what', "wha't", ['and', 'see', 'Mr.'])
# ('happened', 'happon', ['teaching', 'us', 'we'])
# ('stolen', 'stowlen', ['made', 'a', 'magazine'])
# ('please', 'pleas', ['are', 'well', 'and'])
# ('there', 'their', ['up', 'in', 'the'])
# ('too', 'to', ['you', 'come', 'down'])
# ('lately', 'latley', ['house', 'this', 'year'])
# ('babies', 'babyes', ['am', 'this', 'letter'])
# ('being', 'been', ['school', 'it', 'is'])
# ('stolen', 'stowlen', ['hot', 'day', 'our'])
# ('killed', 'killd', ['I', 'tell', 'you'])
# ('want', "whan't", ['her', 'name', 'is'])
# ('want', "whan't", ['but', 'she', 'like'])
# ('doing', 'dowing', ['me', 'we', 'have'])
# ('worried', 'worred', [])
# ('nervous', 'nerves', [])
# ('threw', 'through', [])
# ('happened', 'happen', [])
# ('Oh', 'Ow', [])
# ('crikey', 'crigckey', [])
# ("there's", 'theres', [])
# ('policeman', 'police man', [])
# ('outside', 'out side', [])
# ('pavement', 'pathment', [])
# ('what', "wha't", [])
# ('know', 'now', [])
# ('basket', 'barscket', [])
# ('clothes', 'clous', [])
# ('know', 'now', [])
# ('off', 'of', [])
# ('ordinary', 'ordenrey', [])
# ('know', 'now', [])
# ('what', "wha't", [])
# ('basket', 'baskek', [])
# ('take', 'thack', [])
# ('laundry', 'lordery', [])
# ('What', "Wh't", [])
# ('shuffling', 'shufarling', [])
# ('basket', 'basckek', [])
# ('please', 'pleas', [])
# ("you're", 'your', [])
# ('see', 'se', [])
# ('what', "wha't", [])
# ("you're", 'your', [])
# ('hear', 'here', [])
# ('stole', 'stowl', [])
# ('policeman', 'police man', [])
# ('blew', 'blow', [])
# ('whistle', 'wiscell', [])
# ('policemen', 'police men', [])
# ('far', 'fare', [])
# ('before', 'befor', [])
# ('policeman', 'police man', [])
# ('caught', 'cought', [])
# ('struggled', 'strogald', [])
# ('a bit', 'abit', [])
# ('calmed', 'carmd', [])
# ('station', 'stastione', [])
# ('statement', 'statmeant', [])
# ('jail', 'jaell', [])
# ('two', 'to', [])
# ('babies', 'babyis', [])
# ('lady', 'ladys', [])
# ('whose', 'who', [])
# ('stolen', 'stowle', [])
# ('safely', 'safaly', [])
# ('draw', 'drew', [])
# ('Bang', 'Bankg', [])
# ('straight', 'staidght', [])
# ('Bang', 'Bankg', [])
# ('Bang', 'Bankg', [])
# ('Bang', 'Bankg', [])
# ('your', 'yor', [])
# ('there', 'thre', [])
# ('myself', 'my self', [])
# ('dad', 'bad', [])
# ('My', 'By', [])
# ('dad', 'bad', [])
# ('electrician', 'elecenician', [])
# ('does', 'dus', [])
# ('housework', 'housee work', [])
# ('nearly', 'kneeling', [])
# ('Which', 'Wiich', [])
# ('Note', 'Noet', [])
# ('wait', 'weight', [])
# ('minutes', 'mine', [])
# ('with', 'wiht', [])
# ('two', 'to', [])
# ('policemen', 'policeman', [])
# ("man's", 'man', [])
# ('friend', 'fenird', [])
# ("Dog's", 'Dog', [])
# ('friend', 'fenird', [])
# ('body', 'bod', [])
# ('too', 'to', [])
# ('dirty', 'driy', [])
# ('too', 'to', [])
# ('another', 'a nother', [])
# ('woman', 'womon', [])
# ('Kidneys', 'Kidney', [])
# ('ate', 'eat', [])
# ('killed', 'kill', [])
# ('kidneys', 'kidney', [])
# ('ate', 'eat', [])
# ('had', 'hab', [])
# ('two', 'to', [])
# ('woman', 'wamon', [])
# ('killed', 'kill', [])
# ('Next', 'Nexe', [])
# ('marshland', 'marshladn', [])
# ('footprints', 'foodprints', [])
# ('Factory', 'Facttoer', [])
# ('coming', 'comeing', [])
# ('went', 'wet', [])
# ('on', 'hon', [])
# ('some', 'shm', [])
# ('captain', 'captman', [])
# ('took', 'thc', [])
# ('us', 'hus', [])
# ('out', 'hot', [])
# ('on', 'hn', [])
# ('our', 'out', [])
# ('went', 'wet', [])
# ('on', 'hon', [])
# ('was', 'wos', [])
# ('went', 'wet', [])
# ('captain', 'catptman', [])
# ('motor-cruiser', 'motor-cruisr', [])
# ('on', 'hon', [])
# ('told', 'tod', [])
# ('told', 'tod', [])
# ('disposal', 'disposol', [])
# ('they', 'thror', [])
# ('they', 'thrar', [])
# ('put', 'pht', [])
# ("Frogmen's", 'Frgmens', [])
# ('went', 'wet', [])
# ('there', 'thaw', [])
# ('for', 'fo', [])
# ('they', 'thrar', [])
# ('chain', 'choin', [])
# ('held', 'hasld', [])
# ('they', 'thrar', [])
# ('horns', 'horn', [])
# ('it', 'hit', [])
# ('went', 'wit', [])
# ('boy', 'buy', [])
# ('heard', 'her', [])
# ('his', 'is', [])
# ('run away', 'runaway', [])
# ('uncle', 'unlce', [])
# ('Southwold', 'Suothwode', [])
# ('orphaned', 'orphaed', [])
# ('there', 'thrar', [])
# ('Boys', 'Boy', [])
# ('Boys', 'Boy', [])
# ('went', 'wnet', [])
# ('play', 'payer', [])
# ('made', 'mayd', [])
# ('den', 'dener', [])
# ('Fire', 'Fiyer', [])
# ('Farmer', 'Frameman', [])
# ('gun', 'gon', [])
# ('fired', 'fiyed', [])
# ('hit', 'hiter', [])
# ('Boys', 'Boy', [])
# ('orphaned', 'ophoned', [])
# ('beat', 'pit', [])
# ('him', 'im', [])
# ('went', 'wet', [])
# ('?', 'Doc chm', [])
# ('shot', 'sot', [])
# ('was', 'wos', [])
# ('alright', 'or rit', [])
# ('END', 'HED', [])
# ('from', 'fom', [])
# ('saw', 'sor', [])
# ('door', 'dor', [])
# ('opened', 'oped', [])
# ('walked', 'wocer', [])
# ('went', 'wend', [])
# ('downstairs', 'dau sosys', [])
# ('saw', 'sor', [])
# ('hole', 'holler', [])
# ('?', 'saffrery', [])
# ('went', 'wet', [])
# ('over', 'hover', [])
# ('found', 'feod', [])
# ('?', 'pelser', [])
# ('the', 'thoy', [])
# ('?', 'cHmer', [])
# ('END', 'EDH', [])
# ('cinema', 'cinama', [])
# ('cinema', 'cinama', [])
# ('off', 'of', [])
# ('boyfriend', 'boyfreind', [])
# ('alone', 'a lone', [])
# ('cinema', 'cinama', [])
# ('engaged', 'ingaged', [])
# ('engaged', 'ingaged', [])
# ("o'clock", 'oclock', [])
# ('said', 'siad', [])
# ('their', 'there', [])
# ('amusements', 'amusments', [])
# ('amusements', 'amusments', [])
# ('said', 'siad', [])
# ("let's", 'lets', [])
# ("o'clock", 'oclock', [])
# ('unexpected', 'unispected', [])
# ('comfortable', 'comvatable', [])
# ('crapped', 'crept', [])
# ('lay', 'laid', [])
# ('here', 'hear', [])
# ('crept', 'creeped', [])
# ('captain', 'captian', [])
# ('aboard', 'abroard', [])
# ("I'll", 'ile', [])
# ('off', 'of', [])
# ("don't", 'dont', [])
# ('home', 'hime', [])
# ("don't", 'dont', [])
# ("it's", 'its', [])
# ("it's", 'its', [])
# ('runway', 'runaway', [])
# ('its', 'is', [])
# ("it's", 'its', [])
# ('lying', 'laying', [])
# ("it's", 'its', [])
# ('there', 'the', [])
# ('dump', 'pump', [])
# ('two', 'to', [])
# ('girlfriends', 'girlfriend', [])
# ('and', 'an', [])
# ('bicycles', 'bciyle', [])
# ('brother', 'borther', [])
# ('got', 'go', [])
# ('there', 'ther', [])
# ('bedrooms', 'bed room', [])
# ('got', 'go', [])
# ('player', 'playa', [])
# ('looking', 'look', [])
# ('his', 'is', [])
# ('his', 'is', [])
# ('his', 'is', [])
# ('eyes', 'eye', [])
# ('department', 'depatment', [])
# ('looks', 'look', [])
# ('Pleased', 'Please', [])
# ('starts', 'start', [])
# ('tomorrow', 'to morrow', [])
# ('his', 'is', [])
# ('morning', 'morring', [])
# ('comes', 'come', [])
# ('gets', 'get', [])
# ('gets', 'get', [])
# ('ready', 'realy', [])
# ('got', 'go', [])
# ('at', 'are', [])
# ('gets', 'get', [])
# ('Boss', 'Bos', [])
# ('something', 'some thing', [])
# ('to', 'the', [])
# ('them', 'then', [])
# ('got', 'go', [])
# ('police', 'poicle', [])
# ('police', 'poicle', [])
# ('there', 'ther', [])
# ('police', 'poicle', [])
# ('got', 'go', [])
# ('boss', 'bos', [])
# ('lorry', 'lord', [])
# ('department', 'departent', [])
# ('snakes', 'snake', [])
# ('his', 'is', [])
# ("don't", 'dont', [])
# ('sees', 'see', [])
# ('playing', 'play', [])
# ('picked', 'pick', [])
# ('away', 'a way', [])
# ('shouting', 'shout', [])
# ("boy's", 'boy', [])
# ('her', 'there', [])
# ('running', 'run', [])
# ('where', 'were', [])
# ("don't", 'don', [])
# ('know', 'on', [])
# ('off', 'of', [])
# ('get', 'gett', [])
# ('men', 'man', [])
# ('search', 'seach', [])
# ('for', 'of', [])
# ('looked', 'look', [])
# ('everywhere', 'evry were', [])
# ('found', 'find', [])
# ("boy's", 'boy', [])
# ('can', 'cane', [])
# ('his', 'is', [])
# ('no', 'on', [])
# ("won't", 'won', [])
# ('when', 'went', [])
# ('here', 'hear', [])
# ('as', 'has', [])
# ('alley', 'ally', [])
# ('jumped', 'jump', [])
# ('on', 'one', [])
# ('anyone', 'any one', [])
# ('jumped', 'jump', [])
# ('his', 'is', [])
# ('switched', 'switch', [])
# ('off', 'of', [])
# ('no one', 'not one', [])
# ('missed', 'miss', [])
# ('boys', 'boy', [])
# ('ran', 'run', [])
# ('tree', 'three', [])
# ('suddenly', 'senddly', [])
# ('shouted', 'shout', [])
# ('here', 'hear', [])
# ('here', 'hear', [])
# ('coming', 'come', [])
# ('go', 'got', [])
# ('without', 'with out', [])
# ('stopped', 'stop', [])
# ('weeks', 'week', [])
# ('opened', 'opon', [])
# ('off', 'of', [])
# ('called', 'call', [])
# ('belongs', 'belong', [])
# ("ripper's", 'ripper', [])
# ('looked', 'look', [])
# ('looked', 'look', [])
# ('everywhere', 'every were', [])
# ('got', 'go', [])
# ('looked', 'look', [])
# ('knocked', 'knock', [])
# ('gone', 'go', [])
# ('goes', 'go', [])
# ('after', 'half', [])
# ('got', 'go', [])
# ('alley', 'ally', [])
# ('could', 'call', [])
# ('he', 'ther', [])
# ('charged', 'change', [])
# ('years', 'year', [])
# ('ago', 'a go', [])
# ('pay', 'paid', [])
# ('nights', 'night', [])
# ('Stanley', 'Stanlay', [])
# ('drives', 'drive', [])
# ('steak', 'stack', [])
# ('steak', 'stack', [])
# ('stewing', 'stawing', [])
# ('steak', 'stack', [])
# ('beef', 'bf', [])
# ('where', 'were', [])
# ('when', 'went', [])
# ('nights', 'night', [])
# ('too', 'to', [])
# ('friends', 'frend', [])
# ('Tommy', 'Tomy', [])
# ('an', 'and', [])
# ('got', 'go', [])
# ('push-bicycle', 'pusbycile', [])
# ('going', 'go', [])
# ('tonight', 'to night', [])
# ('got', 'go', [])
# ('at', 'a', [])
# ('her', 'he', [])
# ("what's", 'whats', [])
# ('splendid', 'splended', [])
# ("you're", 'your', [])
# ('too', 'to', [])
# ("o'clock", 'oclock', [])
# ("what's", 'whats', [])
# ('tomorrow', 'tommorrow', [])
# ("we're", 'were', [])
# ("let's", 'lets', [])
# ("there's", 'theres', [])
# ("let's", 'lets', [])
# ('too', 'to', [])
# ("Let's", 'Lets', [])
# ('shining', 'shinning', [])
# ('go', 'got', [])
# ('want', 'wand', [])
# ('wavy', 'wavey', [])
# ('his', "he's", [])
# ('postcards', 'post cards', [])
# ("days'", "day's", [])
# ("weren't", "were'nt", [])
# ('nurses', "nurse's", [])
# ('their', 'there', [])
# ('my', 'may', [])
# ("daddy's", 'dadies', [])
# ('taking', 'takeing', [])
# ("it's", 'its', [])
# ('Comment allez-vous', 'Comatalevous', [])
# ('Comment allez-vous', 'Comatalevous', [])
# ('monsieur', 'missiour', [])
# ('senor', 'senour', [])
# ('pretty', 'preety', [])
# ('prettiest', 'pretiest', [])
# ('private', 'privait', [])
# ('secretary', 'secutery', [])
# ("o'clock", 'oclock', [])
# ("o'clock", 'oclock', [])
# ('evening', 'evning', [])
# ('lived', 'live', [])
# ('away', 'a way', [])
# ('married', 'marreid', [])
# ('the', 'thee', [])
# ('run', 'ran', [])
# ("o'clock", 'oclock', [])
# ('anything', 'anythink', [])
# ('registry', 'registery', [])
# ('they', 'the', [])
# ('celebrated', 'celebrate', [])
# ("o'clock", 'oclock', [])
# ('his', 'he', [])
# ("that's", 'thats', [])
# ('your', 'youre', [])
# ('yes', 'yet', [])
# ('think', 'thing', [])
# ('waggon', 'wagon', [])
# ('indian', 'inded', [])
# ('waggon', 'wagon', [])
# ('waggon', 'wagon', [])
# ('Lone', 'Long', [])
# ('Ranger', 'Rango', [])
# ('knit', 'knitt', [])
# ('photo', 'phto', [])
# ('cannot', 'connot', [])
# ("let's", 'lets', [])
# ('christmas', 'christman', [])
# ('beautiful', 'beaufiful', [])
# ('be', 'by', [])
# ('displaying', 'dispiaying', [])
# ('nearest', 'nearst', [])
# ('says', 'say', [])
# ('yourself', 'yourseff', [])
# ('Thinking', 'Thinkng', [])
# ('few', 'faw', [])
# ('sooner', 'sonner', [])
# ('sex', 'ses', [])
# ('gives', 'give', [])
# ('sexual', 'exual', [])
# ('stimulated', 'simulated', [])
# ('principle', 'principl', [])
# ('policeman', 'policman', [])
# ('for', 'fur', [])
# ('comes', 'come', [])
# ('telephoned', 'telephone', [])
# ('there', 'he', [])
# ('character', 'characte', [])
# ('screen', 'seveen', [])
# ('enjoys', 'enyays', [])
# ('possess', 'passess', [])
# ('vernacular', 'veracular', [])
# ('nearly', 'neally', [])
# ('outfit', 'out fit', [])
# ('Once', 'Ones', [])
# ('upon', 'apen', [])
# ('downstairs', 'down stairs', [])
# ('watch', 'wacth', [])
# ('what', 'whats', [])
# ('manager', 'maneger', [])
# ('said', 'siad', [])
# ("we'll", 'wel', [])
# ('yes', 'yess', [])
# ("I'll", 'Ill', [])
# ('pictures', 'picture', [])
# ('got', 'get', [])
# ('nanny', 'nana', [])
# ('Every', 'Evey', [])
# ('every', 'evey', [])
# ("there's", 'theres', [])
# ('clothes', 'cloths', [])
# ('loved', 'love', [])
# ('Beryl', 'Beryil', [])
# ('Beryl', 'Beryil', [])
# ('Beryl', 'Beryil', [])
# ("there'll", 'therell', [])
# ("don't", 'dont', [])
# ('Doctor', 'Docter', [])
# ('Toby', 'Tobe', [])
# ("it's", 'its', [])
# ('single', 'singl', [])
# ('too', 'to', [])
# ("haven't", "havn't", [])
# ('round about', 'roundabout', [])
# ('disappeared', 'disapeared', [])
# ('should', 'shoud', [])
# ("don't", 'dont', [])
# ('know', 'no', [])
# ('where', 'were', [])
# ("doesn't", 'dosnt', [])
# ("don't", 'dont', [])
# ('There', 'Ther', [])
# ('something', 'somthing', [])
# ('grabbed', 'grabed', [])
# ('no', 'know', [])
# ('then', 'they', [])
# ("couldn't", 'count', [])
# ('too', 'to', [])
# ("we'll", 'well', [])
# ('sometimes', 'some times', [])
# ('then', 'than', [])
# ("can't", 'cant', [])
# ('started', 'startes', [])
# ('quarrel', 'qurral', [])
# ('decided', 'desided', [])
# ('also', 'als', [])
# ('guided', 'guard', [])
# ('programme', 'programe', [])
# ('off', 'of', [])
# ('told', 'to', [])
# ('upstairs', 'up stairs', [])
# ('peeped', 'peped', [])
# ('outside', 'out side', [])
# ('kitchen', 'kitchin', [])
# ("can't", 'cant', [])
# ('downstairs', 'down stairs', [])
# ('upstairs', 'up stairs', [])
# ('listened', 'lisinid', [])
# ('sometimes', 'sometime', [])
# ('creeps', 'creaps', [])
# ("don't", 'dont', [])
# ('downstairs', 'down stairs', [])
# ("don't", 'dont', [])
# ("wasn't", 'wasnt', [])
# ('upstairs', 'up stairs', [])
# ('no', 'know', [])
# ('off', 'of', [])
# ("that's", 'thats', [])
# ("don't", 'dont', [])
# ('suppose', 'surpose', [])
# ("won't", 'wont', [])
# ('off', 'of', [])
# ('really', 'realy', [])
# ('kissed', 'kiss', [])
# ('Once', 'Ones', [])
# ('past', 'pass', [])
# ('happened', 'happend', [])
# ("what's", 'whats', [])
# ('matter', 'mater', [])
# ("it's", 'its', [])
# ("it's", 'its', [])
# ("I'd", 'Id', [])
# ('fine', 'find', [])
# ('lamb', 'lam', [])
# ("aren't", 'arent', [])
# ("it's", 'its', [])
# ("I'll", 'Ill', [])
# ("wasn't", 'wasnt', [])
# ("let's", 'lets', [])
# ("I'd", 'Id', [])
# ("I'll", 'Ill', [])
# ('stories', 'story', [])
# ('cried', 'cryed', [])
# ('babies', 'babys', [])
# ('Babies', 'Babys', [])
# ('your', 'you', [])
# ('dear', 'dead', [])
# ('stars', 'stare', [])
# ('COMMENTARY', 'COMENTARY', [])
# ('Ferrari', 'Farrari', [])
# ('lead', 'leeding', [])
# ('leading', 'lead', [])
# ('Brabham', 'Barham', [])
# ('Brabham', 'Barham', [])
# ('Brabham', 'Barham', [])
# ('through', 'thruogth', [])
# ('going', 'gying', [])
# ('Brabham', 'barham', [])
# ("what's", 'what', [])
# ('happened', 'heap', [])
# ('hear', 'haer', [])
# ('misfiring', 'miss fireing', [])
# ('Cooper', 'Copper', [])
# ('Phil Hill', 'Phillhill', [])
# ('changed', 'cage', [])
# ('still', 'sill', [])
# ('here', 'hear', [])
# ('racing', 'raceing', [])
# ('still', 'sill', [])
# ('speaking', 'seking', [])
# ('quite', 'quit', [])
# ('crash', 'crush', [])
# ('here', 'hear', [])
# ('quit', 'quite', [])
# ('drivers', 'divers', [])
# ('behind', 'behed', [])
# ('killed', 'kill', [])
# ('their', 'theer', [])
# ('spectators', 'spectatoes', [])
# ('engines', 'egreers', [])
# ('ferrari', 'ferrary', [])
# ('still', 'sill', [])
# ('lead', 'led', [])
# ('April', 'Apirl', [])
# ('here', 'hear', [])
# ('April', 'Apirl', [])
# ('when', 'where', [])
# ('trees', 'tree', [])
# ('blossom', 'blossm', [])
# ('flowers', 'flower', [])
# ('July', 'Jluy', [])
# ('months', 'mouth', [])
# ('reap', 'reper', [])
# ('nights', 'nigth', [])
# ('tractor', 'trator', [])
# ('field', 'feild', [])
# ('weasel', 'wasel', [])
# ('gamekeeper', 'gamekeeps', [])
# ('tree', 'treee', [])
# ('too', 'to', [])
# ('cannot', 'can not', [])
# ('difficult', 'differcult', [])
# ('difficult', 'differcult', [])
# ("doesn't", "does'nt", [])
# ('absolutely', 'absolutly', [])
# ('concentrate', 'consantrate', [])
# ('listen', 'listern', [])
# ('punctuation', 'puntuation', [])
# ("you're", 'your', [])
# ('thinking', 'tinking', [])
# ('takes', 'tacks', [])
# ('these', 'thoese', [])
# ('stories', 'story', [])
# ('should', 'shoold', [])
# ('form', 'frame', [])
# ('too', 'to', [])
# ('be coming', 'became', [])
# ('our', 'hour', [])
# ('writing', 'writeing', [])
# ('heat', 'heart', [])
# ("girlfriend's", 'girl friend', [])
# ('fell', 'fall', [])
# ('once', 'own', [])
# ("doesn't", 'does on', [])
# ('getting', 'geting', [])

# %% [markdown]
# # Raw code

# %%
import re
import math
from collections import Counter

# === Utility Functions ===
def words(text):
    return re.findall(r'\w+', text.lower())

# === Load Corpus and Build Models ===
with open('data/big.txt', 'r') as f:
    corpus_text = f.read()

# Unigram model
WORDS = Counter(words(corpus_text))

# Build a bigram model from the corpus.
def build_bigram_model(text):
    tokens = words(text)
    bigrams = zip(tokens, tokens[1:])
    return Counter(bigrams)

BIGRAMS = build_bigram_model(corpus_text)
VOCAB_SIZE = len(WORDS)

def unigram_probability(word, N=sum(WORDS.values())):
    return WORDS[word] / N

def bigram_probability(prev, word):
    # Using add-one smoothing.
    return (BIGRAMS.get((prev, word), 0) + 1) / (WORDS[prev] + VOCAB_SIZE)

# === Norvig's Baseline Correction Functions (Unigram-based) ===
def P(word, N=sum(WORDS.values())):
    "Probability of `word`."
    return WORDS[word] / N

def candidates(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words_list):
    "The subset of `words_list` that appear in the dictionary of WORDS."
    return set(w for w in words_list if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

def correction(word):
    "Most probable spelling correction for word using unigram frequencies."
    return max(candidates(word), key=P)

def ranked_candidates(word):
    "Return candidates sorted by probability in descending order."
    return sorted(candidates(word), key=P, reverse=True)

# === Context-Sensitive Correction (N-gram based) ===
def get_sentence_context(sentence, error_token):
    """
    Given a sentence and an erroneous token, extract the immediate left and right context.
    This function first removes error markers from the sentence.
    Returns (left_context, right_context). If not found, returns (None, None).
    """
    # Remove error markers from the sentence.
    clean_sentence = re.sub(r'<ERR\s+targ=[^>]+>', '', sentence)
    clean_sentence = re.sub(r'</ERR>', '', clean_sentence)
    tokens = words(clean_sentence)
    error_token = error_token.lower()
    if error_token in tokens:
        index = tokens.index(error_token)
        left = tokens[index - 1] if index > 0 else None
        right = tokens[index + 1] if index < len(tokens) - 1 else None
        return left, right
    return None, None

def score_candidate_ngram(candidate, left, right):
    """
    Compute a score for a candidate correction using the unigram probability
    and, if available, the bigram probabilities with left and right context.
    """
    score = unigram_probability(candidate)
    if left:
        score *= bigram_probability(left, candidate)
    if right:
        score *= bigram_probability(candidate, right)
    return score

def ranked_candidates_ngram(erroneous, sentence):
    """
    Return candidates sorted by a context-sensitive score.
    """
    left, right = get_sentence_context(sentence, erroneous)
    cand_list = list(candidates(erroneous))
    ranked = sorted(cand_list, key=lambda w: score_candidate_ngram(w, left, right), reverse=True)
    return ranked

def correction_ngram(erroneous, sentence):
    "Context-sensitive correction using n-gram probabilities."
    ranked = ranked_candidates_ngram(erroneous, sentence)
    return ranked[0] if ranked else erroneous

# === Error Instance Extraction Functions ===
def extract_error_instances(text):
    """
    Extract error instances from the text.
    Each instance is a tuple: (erroneous token, gold (target) token)
    """
    pattern = r'<ERR\s+targ=([^>]+)>\s*([^<]+)\s*</ERR>'
    matches = re.findall(pattern, text)
    return [(err.strip(), targ.strip()) for targ, err in matches]

def extract_error_instances_with_context(text):
    """
    Extract error instances along with their sentence context.
    Returns a list of tuples: (erroneous token, gold token, sentence)
    """
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())
    instances = []
    pattern = r'<ERR\s+targ=([^>]+)>\s*([^<]+)\s*</ERR>'
    for sentence in sentences:
        matches = re.findall(pattern, sentence)
        for targ, err in matches:
            instances.append((err.strip(), targ.strip(), sentence))
    return instances

# === Benchmark Evaluation Code ===
def evaluate_corrections(text, correction_func, use_context=False):
    """
    Evaluate the correction function on all extracted error tokens from the given text.
    Computes token-level accuracy and Mean Reciprocal Rank (MRR) if ranked candidate lists are available.
    """
    if use_context:
        error_instances = extract_error_instances_with_context(text)
    else:
        base_instances = extract_error_instances(text)
        error_instances = [(err, targ, None) for err, targ in base_instances]
    
    correct_count = 0
    total = len(error_instances)
    mrr_total = 0.0
    
    print("=== Evaluating Corrections ===")
    for erroneous, expected, sentence in error_instances:
        # Get ranked candidates depending on whether context is used.
        if use_context and sentence is not None:
            ranked = ranked_candidates_ngram(erroneous, sentence)
            predicted = ranked[0] if ranked else erroneous
        else:
            ranked = ranked_candidates(erroneous)
            predicted = ranked[0] if ranked else erroneous
        
        # Compute reciprocal rank (1-indexed). If expected is not found, RR is 0.
        try:
            rank = ranked.index(expected) + 1
            reciprocal_rank = 1 / rank
        except ValueError:
            reciprocal_rank = 0
        
        mrr_total += reciprocal_rank
        is_correct = predicted == expected
        print(f"Sentence: {sentence}")
        print(f"Input: '{erroneous}' | Ranked Candidates: {ranked} | Predicted: '{predicted}' | Expected: '{expected}'")
        print(f"Correct: {is_correct} | Reciprocal Rank: {reciprocal_rank:.2f}\n")
        if is_correct:
            correct_count += 1
    
    accuracy = (correct_count / total) if total > 0 else 0
    mrr = (mrr_total / total) if total > 0 else 0
    print(f"Token-Level Correction Accuracy: {accuracy * 100:.2f}%")
    print(f"Mean Reciprocal Rank (MRR): {mrr:.2f}")
    return accuracy, mrr

# === Sentence-Level Perplexity Evaluation ===
def sentence_perplexity(sentence):
    """
    Compute the perplexity of a sentence using the bigram model with add-one smoothing.
    """
    tokens = words(sentence)
    if len(tokens) < 2:
        return float('inf')
    log_prob = 0.0
    for i in range(1, len(tokens)):
        prev, curr = tokens[i - 1], tokens[i]
        prob = bigram_probability(prev, curr)
        log_prob += math.log(prob)
    avg_log_prob = log_prob / (len(tokens) - 1)
    perplexity = math.exp(-avg_log_prob)
    return perplexity

def evaluate_sentence_level(text, correction_func, use_context=False):
    """
    For each sentence, replace erroneous tokens with corrections and compute
    the sentence-level perplexity before and after correction.
    """
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())
    total_before = 0.0
    total_after = 0.0
    count = 0
    print("=== Sentence-Level Perplexity Evaluation ===")
    for sentence in sentences:
        original_sentence = sentence
        corrected_sentence = sentence
        # Find all error markers in the sentence.
        pattern = r'<ERR\s+targ=([^>]+)>\s*([^<]+)\s*</ERR>'
        matches = re.findall(pattern, sentence)
        for targ, err in matches:
            if use_context:
                correction_token = correction_ngram(err.strip(), sentence)
            else:
                correction_token = correction(err.strip())
            # Replace the error marker with the correction.
            corrected_sentence = corrected_sentence.replace(f"<ERR targ={targ}> {err} </ERR>", correction_token)
        # For the "before" version, simply remove the error markers.
        cleaned_original = re.sub(r'<ERR\s+targ=[^>]+>\s*([^<]+)\s*</ERR>', r'\1', original_sentence)
        pp_before = sentence_perplexity(cleaned_original)
        pp_after = sentence_perplexity(corrected_sentence)
        print(f"Original: {cleaned_original}")
        print(f"Corrected: {corrected_sentence}")
        print(f"Perplexity Before: {pp_before:.2f} | After: {pp_after:.2f}\n")
        total_before += pp_before
        total_after += pp_after
        count += 1
    avg_before = total_before / count if count > 0 else float('inf')
    avg_after = total_after / count if count > 0 else float('inf')
    print(f"Average Sentence Perplexity - Before Correction: {avg_before:.2f}")
    print(f"Average Sentence Perplexity - After Correction: {avg_after:.2f}")
    return avg_before, avg_after

# === Example Usage with Provided Test Data ===
if __name__ == "__main__":
    test_text = """
    I have four in my Family Dad Mum and <ERR targ=sister> siter </ERR> .
    My Dad works at Melton.
    My <ERR targ=sister> siter </ERR> <ERR targ=goes> go </ERR> to Tonbury.
    My Mum goes out <ERR targ=sometimes> some times </ERR> .
    I go to Bridgebrook i go out <ERR targ=sometimes> some times </ERR> on Tuesday night i go to Youth <ERR targ=club> clob </ERR> .
    On thursday nights I go <ERR targ=bellringing> bell ringing </ERR> on Saturdays I go down to the farm.
    on sundays I go to church.
    I go to bed at 10 o clock I <ERR targ=watch> wakh </ERR> TV at 5 o clock I live in a house.
    The house is in the world.
    I live at Boar Parva it is near Melton and Bridgebrook and Smallerden.
    The house is white it has stone up the <ERR targ=front> frount </ERR> it is the first from Bridgebrook and the <ERR targ=second> sexeon </ERR> from Smallerden.
    My Mum is at home She goes to the shop on fridays My Dad goes to work at Smallerden .
    
    What I do when I get home from school.
    On monday I sometimes go down the farm in the night I <ERR targ=watch> wach </ERR> TV there is BBC and I.T.V.
    I like I.T.V.
    We call Anglia I.T.V.
    We have got Anglia like to <ERR targ=watch> wach </ERR> <ERR targ=cowboys> cow Boys </ERR> .
    On Tuesday I get off the bus and <ERR targ=sometimes> some times </ERR> in the night I go to the Youth <ERR targ=club> colbe </ERR> .
    I like to <ERR targ=watch> wach </ERR> T.V.
    there is a lot of things on T.V.
    I <ERR targ=watch> wach </ERR> it each night.
    I <ERR targ=think> thing </ERR> <ERR targ=TV> tv </ERR> is good but people say it gives us <ERR targ=square> squar </ERR> <ERR targ=eyes> iyes </ERR>
    """
    
    print("=== Baseline Unigram Correction Evaluation ===")
    evaluate_corrections(test_text, correction, use_context=False)
    
    print("\n=== Context-Sensitive N-gram Correction Evaluation ===")
    evaluate_corrections(test_text, correction_ngram, use_context=True)
    
    print("\n=== Sentence-Level Perplexity Evaluation (Baseline) ===")
    evaluate_sentence_level(test_text, correction, use_context=False)
    
    print("\n=== Sentence-Level Perplexity Evaluation (Context-Sensitive) ===")
    evaluate_sentence_level(test_text, correction_ngram, use_context=True)
